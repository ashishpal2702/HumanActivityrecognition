# %% [markdown]
# # Batch Time and Real-time Prediction

# %%
# Importing the necessary library
import boto3
import sagemaker
import pandas as pd
from joblib import dump, load
import s3fs

# %%
# Initialising new sagemaker session as "sess".
sess = sagemaker.Session()
# Bucket variable is used for storing the location of the bucket
bucket = 'sagemaker-studio-009676737623-l4vs7j0o0ib'
# Assigning the prefix variable
prefix = 'mlops-level1-data'
# Check for necessary permission needed for training and deploying models. 
role = sagemaker.get_execution_role()
# To understand where this session is configured to operate.
region = boto3.Session().region_name

# %% [markdown]
# ## Test Data

# %%
# Creating a string for the test path 
test_data_path = f's3://{bucket}/{prefix}/test_data.csv'

# %%
# Importing the dataset
test_data = pd.read_csv(test_data_path)
test_data.shape
# Out:
# (610, 562)

# %%
# Treating missing values
test_data.isna().sum()
test_data.dropna(inplace = True)
test_data.shape
# Out:
# (609, 562)

# %%
## Get Features
fs = s3fs.S3FileSystem() # Updated method name
filename = f's3://{bucket}/{prefix}/feature/feature.joblib'
with fs.open(filename, encoding='utf8') as fh:
    cols = load(fh)

## Get Encoder object
filename = f's3://{bucket}/{prefix}/feature/encoder.joblib'
with fs.open(filename, encoding='utf8') as fh:
    encoder = load(fh)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 0.23.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
cols
# Out:
# array(['tGravityAcc-energy()-X', 'tGravityAcc-min()-X',
#        'tGravityAcc-max()-X', 'tGravityAcc-mean()-X',
#        'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y',
#        'fBodyAccJerk-entropy()-X', 'angle(Y,gravityMean)',
#        'tBodyAccMag-max()', 'tBodyAcc-max()-X', 'Activity'], dtype=object)

# %%
processed_test_data = test_data[cols]
test_x = processed_test_data.drop('Activity', axis = 1)
test_y= processed_test_data[['Activity']]
test_x.shape, test_y.shape
# Out:
# ((609, 12), (609, 1))

# %% [markdown]
# ## Save Processed Test to S3

# %%
test_x_path = f"s3://{bucket}/{prefix}/prediction/test/test_x.csv"
test_y_path =f"s3://{bucket}/{prefix}/prediction/test/test_y.csv"
test_x.to_csv(test_x_path, index=False, header=False)
test_y.to_csv(test_y_path, index=False, header=False)

# %% [markdown]
# # Real time Prediction

# %%
client = boto3.client('sagemaker-runtime')

# %%
endpoint_name = 'HumanActivity-InferenceEndpoint-2023-09-25-0546'

# %%
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer, JSONSerializer
from sagemaker.deserializers import CSVDeserializer , JSONDeserializer

predictor_csv = Predictor(endpoint_name=endpoint_name,
                      serializer=CSVSerializer(),
                     deserializer=CSVDeserializer())

# %%
prediction = predictor_csv.predict(test_x.sample(10))

# %% [markdown]
# ### Check Data Capture

# %%
data_capture = 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/datacapture/HumanActivity-InferenceEndpoint-2023-09-25-0546/AllTraffic/2023/09/25/05/52-24-109-c21b0608-1627-419c-b2b4-cb46d0bc9471.jsonl'

275478,-0.3150726,0.6292224000000001,0.29109603,-0.20986489,0.024377874\n0.80269364,0.94595498,0.85487882,0.92628592,-0.68125025,-0.31281082,-0.34107536,-0.35038177,-1.0,0.31683141,-0.98609454,-0.94501777\n-0.95552497,-0.21403178,-0.32126784,-0.25465591,0.43354061,0.95312382,0.94214079,0.89297316,-1.0,-0.80710001,-0.97969197,-0.93664209\n0.78888992,0.94037297,0.84884589,0.92091184,-0.7404593,0.11712951,0.10068558,0.078233772,-1.0,0.014641909,-0.98743499,-0.9414743\n0.88575429,0.97761874,0.88564554,0.95819873,-0.87166806,0.097880181,0.078699799,0.0506055,-1.0,0.029871755,-0.98322341,-0.94088611\n0.79562756,0.94312006,0.84928692,0.92353812,-0.67977531,-0.30188609,-0.32963491,-0.34640884,-1.0,0.30909256,-0.99532997,-0.94333385\n-0.92691522,-0.71024001,-0.8177253000000001,-0.75672502,0.79692828,-0.080349227,-0.05899586,0.090769079,-0.94369895,0.12501854,-0.77393981,-0.92048585\n0.85618709,0.95787983,0.87654171,0.94691727,-0.7601763000000001,-0.2653281,-0.26205559,-0.27383035,0.5718565999999999,0.26295137,-0.27682438,-0.29039716\n-0.92159814,-0.13806245,-0.25109148,-0.18252571,0.38018933,0.86359342,0.85136465,0.80235897,-1.0,-0.64636509,-0.99210627,-0.93076229\n0.8739058000000001,0.96109993,0.89035647,0.95366394,-0.76866085,-0.21020539,-0.23485919,-0.24568607,0.62443478,0.24366469,0.0431331229999999,0.46194193\n0.80454895,0.93038776,0.86599523,0.92698246,-0.69729805,-0.27894839,-0.30575951,-0.32090594,0.63026488,0.29294262,-0.30325133,-0.0530249209999999\n0.83159392,0.95275431,0.86906632,0.93746757,-0.76024173,-0.23571488,-0.25840003,-0.27426143,0.62123349,0.2615288,-0.20045673,-0.091285176\n0.84837673,0.96173723,0.8706033000000001,0.94392635,-0.79338685,0.009230386,-0.004313032,-0.027427094,-1.0,0.086883915,-0.98060964,-0.93415159\n-0.92037077,-0.13595307,-0.24930565,-0.18024748,0.37860514,0.86571388,0.85237181,0.803202 ...
#   'encoding': 'CSV'},
#  'endpointOutput': {'observedContentType': 'text/csv; charset=utf-8',
#   'mode': 'OUTPUT',
#   'data': '3\n1\n1\n5\n1\n3\n0\n5\n2\n1\n1\n0\n4\n1\n2\n3\n2\n0\n1\n1\n2\n0\n3\n0\n4\n3\n3\n1\n0\n3\n1\n3\n1\n1\n0\n0\n5\n1\n1\n2\n2\n2\n0\n5\n2\n1\n5\n0\n4\n2\n0\n1\n1\n2\n2\n0\n2\n3\n5\n3\n2\n3\n2\n0\n2\n3\n3\n2\n2\n3\n3\n2\n4\n1\n2\n3\n4\n3\n3\n1\n5\n3\n1\n3\n3\n5\n3\n4\n5\n0\n3\n0\n1\n2\n1\n2\n3\n3\n2\n1\n',
#   'encoding': 'CSV'}}
