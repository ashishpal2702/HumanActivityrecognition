# %% [markdown]
# # Amazon SageMaker Model Quality Monitor

# %% [markdown]
# ---
#
# This notebook's CI test result for us-west-2 is as follows. CI test results in other regions can be found at the end of the notebook.
#
# ![This us-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/us-west-2/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ---

# %% [markdown]
# #### Host a trained machine learning model in Amazon SageMaker.  Monitor and detect machine learning model quality drift
#
#
# This notebook shows how to:
# * Host a machine learning model in Amazon SageMaker and capture inference requests, results, and metadata
# * Generate a baseline of model quality and suggested constraints
# * Monitor a live endpoint for violations against the suggested constraints
# * Generate CloudWatch Alarms on model quality drift
#
#
# **Table of Contents**
#
# 1. [Introduction](#intro)
# 2. [Section 1 - Setup](#setup)
# 3. [Section 2 - Deploy pre-trained model with data capture enabled](#deploy)
# 5. [Section 3 - Generate baseline for model quality performance](#generate-baseline)
# 6. [Section 4 - Setup continuous model monitoring to identify model quality drift](#analyze-model-quality-drift)
# 7. [Section 5 - Analyze model quality CloudWatch metrics](#analyze-cloudwatch-metrics)
# 8. [Clean up](#cleanup)
#
#
#
# ## Introduction <a id='intro'></a>
#
# Amazon SageMaker provides every developer and data scientist with the ability to build, train, and deploy machine learning (ML) models quickly by bringing together a broad set of capabilities purpose-built for ML. Amazon SageMaker is a fully-managed service that encompasses the entire ML workflow. You can label and prepare your data, choose an algorithm, train a model, and then tune and optimize it for deployment. You can deploy your models to production with Amazon SageMaker to make predictions and lower costs than it was previously possible.
#
# Amazon SageMaker Model Monitor allows you to maintain high quality ML models by automatically detecting and helping you remediate inaccuracies in model predictions. Model Monitor helps
# you detect changes in properties of independent variables to help maintain data quality, and
# monitors model performance characteristics such as accuracy and precision in real-time to
# help maintain model quality.
#
# In this notebook, you learn how to use Amazon SageMaker model quality monitoring capability to monitor model performance characteristics of your in-production ML models. You will learn how to configure Amazon CloudWatch alerts to get notified if the model quality degrades from the configured baseline quality.

# %% [markdown]
# ## Section 1 - Setup <a id='setup'></a>
#
# In this section, you will import the necessary libraries, setup variables and examine data that was used to train the XGBoost customer churn model provided with this notebook.
#
# Let's start by specifying:
#
# * The AWS region used to host your model.
# * The IAM role associated with this SageMaker notebook instance.
# * The S3 bucket used to store the data used to train your model, any additional model data, and the data captured from model invocations.

# %% [markdown]
# #### 1.1 Import necessary libraries

# %%
# %%time

from datetime import datetime, timedelta, timezone
import json
import os
import re
import boto3
from time import sleep
from threading import Thread

import pandas as pd

from sagemaker import get_execution_role, session, Session, image_uris
from sagemaker.s3 import S3Downloader, S3Uploader
from sagemaker.processing import ProcessingJob
from sagemaker.serializers import CSVSerializer

from sagemaker.model import Model
from sagemaker.model_monitor import DataCaptureConfig

session = Session()
# Out:
# CPU times: user 1.31 s, sys: 184 ms, total: 1.49 s
# Wall time: 2.57 s

# %% [markdown]
# #### 1.2 AWS region and  IAM Role

# %%
# Get Execution role
role = get_execution_role()
print("RoleArn:", role)

region = session.boto_region_name
print("Region:", region)
# Out:
# RoleArn: arn:aws:iam::009676737623:role/sagemaker-full-permission
# Region: ap-south-1

# %% [markdown]
# #### 1.3 S3 bucket and prefixes

# %%
# Setup S3 bucket
# You can use a different bucket, but make sure the role you chose for this notebook
# has the s3:PutObject permissions. This is the bucket into which the data is captured
bucket = 'sagemaker-studio-009676737623-l4vs7j0o0ib' #session.default_bucket()
print("Demo Bucket:", bucket)
prefix = 'mlops-level1-data' # "sagemaker/Churn-ModelQualityMonitor-20201201"

##S3 prefixes
data_capture_prefix = f"{prefix}/datacapture"
s3_capture_upload_path = f"s3://{bucket}/{data_capture_prefix}"

ground_truth_upload_path = (
    f"s3://{bucket}/{prefix}/ground_truth_data/{datetime.now():%Y-%m-%d-%H-%M-%S}"
)

reports_prefix = f"{prefix}/reports"
s3_report_path = f"s3://{bucket}/{reports_prefix}"

##Get the model monitor image
monitor_image_uri = image_uris.retrieve(framework="model-monitor", region=region)

print("Image URI:", monitor_image_uri)
print(f"Capture path: {s3_capture_upload_path}")
print(f"Ground truth path: {ground_truth_upload_path}")
print(f"Report path: {s3_report_path}")
# Out:
# Demo Bucket: sagemaker-studio-009676737623-l4vs7j0o0ib
# Image URI: 126357580389.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-model-monitor-analyzer
# Capture path: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/datacapture
# Ground truth path: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/ground_truth_data/2023-09-27-06-31-29
# Report path: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/reports

# %% [markdown]
# ## Section 2 - Deploy pre-trained model with data capture enabled <a id='deploy'></a>
#
# In this section, you will upload the pretrained model to the S3 bucket, create an Amazon SageMaker Model, create an Amazon SageMaker real time endpoint, and enable data capture on the endpoint to capture endpoint invocations, predictions, and metadata.

# %% [markdown]
# #### 2.1 Upload the pre-trained model to S3
#
# This code uploads a pre-trained XGBoost model that is ready for you to deploy. This model was trained using the XGB Churn Prediction Notebook in SageMaker. You can also use your own pre-trained model in this step. If you already have a pretrained model in Amazon S3, you can add it instead by specifying the s3_key.

# %%
##Upload the pretrained model to S3
#s3_key = f"s3://{bucket}/{prefix}"
#model_url = S3Uploader.upload("model/xgb-churn-prediction-model.tar.gz", s3_key)
#model_url

# %%
model_url = f"s3://{bucket}/{prefix}/abalone-xgb-built-in-algo/output/sagemaker-xgboost-2023-09-26-05-47-34-821/output/model.tar.gz"

# %% [markdown]
# #### 2.2 Create SageMaker Model entity
#
# This step creates an Amazon SageMaker model from the  model file uploaded to S3.

# %%
#model_name = f"DEMO-xgb-churn-pred-model-monitor-{datetime.utcnow():%Y-%m-%d-%H%M}"

image_uri = image_uris.retrieve(framework="xgboost", version="1.7-1", region=region)

model = Model(image_uri=image_uri, model_data=model_url, role=role, sagemaker_session=session)

# %% [markdown]
# #### 2.3 Deploy the model with data capture enabled.
# Next, deploy the SageMaker model on a specific instance with data capture enabled.

# %%
endpoint_name = f"DEMO-mlops-xgboost-quality-monitor-{datetime.utcnow():%Y-%m-%d-%H%M}"
print("EndpointName =", endpoint_name)

data_capture_config = DataCaptureConfig(
    enable_capture=True, sampling_percentage=100, destination_s3_uri=s3_capture_upload_path
)

model.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.large",
    endpoint_name=endpoint_name,
    data_capture_config=data_capture_config,
)
# Out:
# EndpointName = DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639
# ----!

# %% [markdown]
# #### 2.4 Create the SageMaker Predictor object from the endpoint to be used for invoking the model

# %%
from sagemaker.predictor import Predictor

predictor = Predictor(
    endpoint_name=endpoint_name, sagemaker_session=session, serializer=CSVSerializer()
)

# %% [markdown]
# ##  Section 3 - Generate a baseline for model quality performance <a id='generate-baseline'></a>
#
# In this section, you will invoke the endpoint created above using validation data. Predictions from the deployed model using this validation data will be used as a baseline dataset.  You will then use SageMaker's Model Monitoring to execute a baseline job that computes model performance data, and suggest model quality constraints based on the baseline dataset.

# %% [markdown]
# #### 3.1 Execute predictions using the validation dataset.
#
# The deployed model returns probability that a customer will churn. Let's choose an arbitrary 0.8 cutoff to consider that a customer will churn.

# %%
churn_cutoff = 0.8
validate_dataset = "validation_with_predictions.csv"

# %%
limit = 200  # Need at least 200 samples to compute standard deviations
i = 0
with open(f"test_data/{validate_dataset}", "w") as baseline_file:
    baseline_file.write("probability,prediction,label\n")  # our header
    with open("test_data/validation.csv", "r") as f:
        for row in f:
            (label, input_cols) = row.split(",", 1)
            probability = float(predictor.predict(input_cols))
            #print(probability)
            #prediction = "1" if probability > churn_cutoff else "0"
            baseline_file.write(f"{probability},{prediction},{label}\n")
            i += 1
            if i > limit:
                break
            print(".", end="", flush=True)
            sleep(0.5)
print()
print("Done!")
# Out:
# ........................................................................................................................................................................................................
# Done!

# %% [markdown]
# #### 3.2 Examine the predictions from the model

# %%
# !head test_data/validation_with_predictions.csv
# Out:
# probability,prediction,label
# 0.0,1,0
# 0.0,1,4
# 0.0,1,4
# 1.0,1,2
# 0.0,1,4
# 1.0,1,1
# 0.0,1,4
# 1.0,1,1
# 0.0,1,3

# %% [markdown]
# #### 3.3 Upload the predictions as a baseline dataset.
# Now we will upload the predictions made using validation dataset to S3 which will be used for creating model quality baseline statistics and constraints

# %%
baseline_prefix = prefix + "/baselining"
baseline_data_prefix = baseline_prefix + "/data"
baseline_results_prefix = baseline_prefix + "/results"

baseline_data_uri = f"s3://{bucket}/{baseline_data_prefix}"
baseline_results_uri = f"s3://{bucket}/{baseline_results_prefix}"
print(f"Baseline data uri: {baseline_data_uri}")
print(f"Baseline results uri: {baseline_results_uri}")
# Out:
# Baseline data uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/data
# Baseline results uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/results

# %%
baseline_dataset_uri = S3Uploader.upload(f"test_data/{validate_dataset}", baseline_data_uri)
baseline_dataset_uri
# Out:
# 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/data/validation_with_predictions.csv'

# %% [markdown]
# #### 3.4 Create a baselining job with validation dataset predictions
# Define the model quality monitoring object and execute the model quality monitoring baseline job. Model monitor will automatically generate baseline statistics and constraints based on the validation dataset provided.

# %%
from sagemaker.model_monitor import ModelQualityMonitor
from sagemaker.model_monitor import EndpointInput
from sagemaker.model_monitor.dataset_format import DatasetFormat

# %%
# Create the model quality monitoring object
mlops_model_quality_monitor = ModelQualityMonitor(
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    volume_size_in_gb=20,
    max_runtime_in_seconds=1800,
    sagemaker_session=session,
)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: .
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
# Name of the model quality baseline job
baseline_job_name = f"DEMO-mlops-xgboost-baseline-job-{datetime.utcnow():%Y-%m-%d-%H%M}"

# %%
# Execute the baseline suggestion job.
# You will specify problem type, in this case Binary Classification, and provide other required attributes.
job = mlops_model_quality_monitor.suggest_baseline(
    job_name=baseline_job_name,
    baseline_dataset=baseline_dataset_uri,
    dataset_format=DatasetFormat.csv(header=True),
    output_s3_uri=baseline_results_uri,
    problem_type="MulticlassClassification",
    inference_attribute="prediction",
    probability_attribute="probability",
    ground_truth_attribute="label",
)
job.wait(logs=False)
# Out:
# INFO:sagemaker:Creating processing-job with name DEMO-mlops-xgboost-baseline-job-2023-09-27-0704
# ............................................................................!

# %% [markdown]
# #### 3.5 Explore the results of the baselining job
# You could see the baseline constraints and statistics files are uploaded to the S3 location.

# %%
baseline_job = mlops_model_quality_monitor.latest_baselining_job

# %% [markdown]
# ##### 3.5.1 View the metrics generated
# You could see that the baseline statistics and constraints files are already uploaded to S3.

# %%
multiclas_metrics = baseline_job.baseline_statistics().body_dict["multiclass_classification_metrics"]
pd.json_normalize(multiclas_metrics).T
# Out:
#                                                             0
# confusion_matrix.4.4                                 0.000000
# confusion_matrix.4.5                                 0.000000
# confusion_matrix.4.1                                29.000000
# confusion_matrix.4.0                                 0.000000
# confusion_matrix.4.2                                 0.000000
# confusion_matrix.4.3                                 0.000000
# confusion_matrix.5.4                                 0.000000
# confusion_matrix.5.5                                 0.000000
# confusion_matrix.5.1                                39.000000
# confusion_matrix.5.0                                 0.000000
# confusion_matrix.5.2                                 0.000000
# confusion_matrix.5.3                                 0.000000
# confusion_matrix.1.4                                 0.000000
# confusion_matrix.1.5                                 0.000000
# confusion_matrix.1.1                                27.000000
# confusion_matrix.1.0                                 0.000000
# confusion_matrix.1.2                                 0.000000
# confusion_matrix.1.3                                 0.000000
# confusion_matrix.0.4                                 0.000000
# confusion_matrix.0.5                                 0.000000
# confusion_matrix.0.1                                36.000000
# confusion_matrix.0.0                                 0.000000
# confusion_matrix.0.2                                 0.000000
# confusion_matrix.0.3                                 0.000000
# confusion_matrix.2.4                                 0.000000
# confusion_matrix.2.5                                 0.000000
# confusion_matrix.2.1                                37.000000
# confusion_matrix.2.0                                 0.000000
# confusion_matrix.2.2                                 0.000000
# confusion_matrix.2.3                                 0.000000
# confusion_matrix.3.4                                 0.000000
# confusion_matrix.3.5                                 0.000000
# confusion_matrix.3.1                                33.000000
# confusion_matrix.3.0                                 0.000000
# confusion_matrix.3.2                                 0.000000
# confusion_matrix.3.3                                 0.000000
# accuracy.value                                       0.134328
# accuracy.standard_deviation                          0.010574
# weighted_recall.value                                0.134328
# weighted_recall.standard_deviation                   0.010574
# weighted_precision.value                             0.018044
# weighted_precision.standard_deviation                0.002796
# weighted_f0_5.value                                  0.021822
# weighted_f0_5.standard_deviation                     0.003329
# weighted_f1.value                                    0.031815
# weighted_f1.standard_deviation                       0.004649
# weighted_f2.value                                    0.058687
# weighted_f2.standard_deviation                       0.007558
# accuracy_best_constant_classifier.value              0.134328
# accuracy_best_constant_classifier.standard_devi...   0.010574
# weighted_recall_best_constant_classifier.value       0.134328
# weighted_recall_best_constant_classifier.standa...   0.010574
# weighted_precision_best_constant_classifier.value    0.018044
# weighted_precision_best_constant_classifier.sta...   0.002796
# weighted_f0_5_best_constant_classifier.value         0.021822
# weighted_f0_5_best_constant_classifier.standard...   0.003329
# weighted_f1_best_constant_classifier.value           0.031815
# weighted_f1_best_constant_classifier.standard_d...   0.004649
# weighted_f2_best_constant_classifier.value           0.058687
# weighted_f2_best_constant_classifier.standard_d...   0.007558

# %% [markdown]
# ##### 3.5.2 View the constraints generated

# %%
pd.DataFrame(baseline_job.suggested_constraints().body_dict["multiclass_classification_constraints"]).T
# Out:
#                    threshold comparison_operator
# accuracy            0.134328   LessThanThreshold
# weighted_recall     0.134328   LessThanThreshold
# weighted_precision  0.018044   LessThanThreshold
# weighted_f0_5       0.021822   LessThanThreshold
# weighted_f1         0.031815   LessThanThreshold
# weighted_f2         0.058687   LessThanThreshold

# %% [markdown]
# In the above example you can see that model quality monitor suggested a constraint that will ensure that the model F2 score should note drop below 0.625. Few generated constraints _may_ be a tad aggressive like precision, where it will alert on any drops below 1.0. It is recommended to modify this file as necessary prior to using for monitoring.

# %% [markdown]
# ##  Section 4 - Setup continuous model monitoring to identify model quality drift <a id='analyze-model-quality-drift'></a>
#
# In this section, you will setup a continuous model monitoring job that monitors the quality of the deployed model against the baseline generated in the previous section.  This is to ensure that the quality does not degrade over time.
#
# In addition to the generated baseline, Amazon SageMaker Model Quality Monitoring needs two additional inputs - predictions made by the deployed model endpoint and the ground truth data to be provided by the model consuming application.  Since you already enabled data capture on the endpoint, prediction data is captured in S3.  The ground truth data depends on the what your model is predicting and what the business use case is.  In this case, since the model is predicting customer churn, ground truth data may indicate if the customer actually left the company or not.  For the purposes of this notebook, you will generate synthetic data as ground truth.

# %% [markdown]
# #### 4.1 Generate prediction data for Model Quality  Monitoring
#
# Start generating some artificial traffic.  The cell below starts a thread to send some traffic to the endpoint. Note that you need to stop the kernel to terminate this thread. If there is no traffic, the monitoring jobs are marked as `Failed` since there is no data to process.

# %%
endpoint_name
# Out:
# 'DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639'

# %%
def invoke_endpoint(ep_name, file_name):
    with open(file_name, "r") as f:
        i = 0
        for row in f:
            payload = row.rstrip("\n")
            response = session.sagemaker_runtime_client.invoke_endpoint(
                EndpointName=ep_name,
                ContentType="text/csv",
                Body=payload,
                InferenceId=str(i),  # unique ID per row
            )["Body"].read()
            i += 1
            sleep(1)


def invoke_endpoint_forever():
    while True:
        try:
            invoke_endpoint(endpoint_name, "test_data/test_x.csv")
        except session.sagemaker_runtime_client.exceptions.ValidationError:
            pass


thread = Thread(target=invoke_endpoint_forever)
thread.start()
# Out:
# erro
# error
# error
# erro
# error
# error
# erro
# error
# erro
# error
# error
# erro
# error
# error
# erro
# errorerror
#
# erroerror
#
# error
# erro
# error
# error
# erro
# error
# error
# erro
# error
# error
# error
# erro
# error
# erro
# erro
# error
# error
# erro
# error
# erro
# error
# error
# erro
# error
# error
# erro
# erro
# error
# error
# error
# error
# erro
# error
# erro
# error
# erro
# error
# error
# erro
# error
# error
# error
# erro
# errorerror
#
# erroerror
#
# error
# error
# error
# erro
# error
# error
# error
# erro
# error
# error
# erro
# error
# error
# erro
# error
# error
# erro
# error
# error
# erro
# error
# erro
# error
# error
# erro
# error
# error
# error
# erro
# error
# error
# erro
# error
# erro
# error
# error
# error
# erro
# error
# erro
# error
# error
# error
# erro
# error
# error
# error
# erro
# error
# error
# errorerro

# %% [markdown]
# Notice the new attribute `inferenceId`, which we're setting when invoking the endpoint. This is used to join the prediction data with the ground truth data.

# %% [markdown]
# #### 4.2 View captured data
#
# Now list the data capture files stored in Amazon S3. You should expect to see different files from different time periods organized based on the hour in which the invocation occurred. The format of the Amazon S3 path is:
#
# `s3://{destination-bucket-prefix}/{endpoint-name}/{variant-name}/yyyy/mm/dd/hh/filename.jsonl`

# %%
print("Waiting for captures to show up", end="")
for _ in range(120):
    capture_files = sorted(S3Downloader.list(f"{s3_capture_upload_path}/{endpoint_name}"))
    if capture_files:
        capture_file = S3Downloader.read_file(capture_files[-1]).split("\n")
        capture_record = json.loads(capture_file[0])
        if "inferenceId" in capture_record["eventMetadata"]:
            break
    print(".", end="", flush=True)
    sleep(1)
print()
print("Found Capture Files:")
print("\n ".join(capture_files[-3:]))
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# Waiting for captures to show up
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# Found Capture Files:
# s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/datacapture/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/AllTraffic/2023/09/27/07/24-24-181-6eba4f19-a42a-486d-a5e3-0ff6e4520084.jsonl
#  s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/datacapture/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/AllTraffic/2023/09/27/07/25-24-684-7acb3806-7746-49a0-82ec-b580ef714ca2.jsonl
#  s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/datacapture/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/AllTraffic/2023/09/27/07/26-24-686-91c42a3c-6b6d-4d14-b932-2907e91894a8.jsonl

# %% [markdown]
# Next, view the contents of a single capture file. Here you should see all the data captured in an Amazon SageMaker specific JSON-line formatted file. Take a quick peek at the first few lines in the captured file.

# %%
print("\n".join(capture_file[-3:-1]))
# Out:
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"-0.1134944744355881,-0.8723077905900494,-0.06484198135702256,-0.02790488159594419,0.07464504967378448,0.060299240906754197,0.09435594162391639,0.2782219856406039,-0.8959968405116706,-0.2451031255132979,-0.8266682730168923,-0.9402987720668232","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"1.0\n","encoding":"CSV"}},"eventMetadata":{"eventId":"8237045c-52a4-4e77-97e9-88a6c8015686","inferenceId":"122","inferenceTime":"2023-09-27T07:27:24Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"0.6067353088340156,0.026406952023398808,0.5989987507110005,0.40254287260358235,-0.5331446229795529,-0.013875857264522071,-0.05969263934167081,-0.07177235275916853,-0.01208292806894684,0.11153573523539237,0.16006395598629886,0.4194590824700791","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"0.0\n","encoding":"CSV"}},"eventMetadata":{"eventId":"295c7913-fb94-4b13-93f0-2a6da057e5c9","inferenceId":"1","inferenceTime":"2023-09-27T07:27:24Z"},"eventVersion":"0"}

# %% [markdown]
# Finally, the contents of a single line is present below in a formatted JSON file so that you can observe a little better.
#
# Again, notice the `inferenceId` attribute that is set as part of the invoke_endpoint call.  If this is present, it will be used to join with ground truth data (otherwise `eventId` will be used):

# %%
print(json.dumps(capture_record, indent=2))
# Out:
# {
#   "captureData": {
#     "endpointInput": {
#       "observedContentType": "text/csv",
#       "mode": "INPUT",
#       "data": "0.3397972349466847,0.47401233237489876,0.44736154602070377,0.20169037293925973,-0.37819238999865135,-0.20465330253254527,-0.07164628158463893,-0.14701018251644118,-0.026483023293890438,0.1427188234575294,-0.175289915679583,-0.26271563191806013",
#       "encoding": "CSV"
#     },
#     "endpointOutput": {
#       "observedContentType": "text/csv; charset=utf-8",
#       "mode": "OUTPUT",
#       "data": "0.0\n",
#       "encoding": "CSV"
#     }
#   },
#   "eventMetadata": {
#     "eventId": "4e38b023-789f-4303-a253-fb7d1ee22fbc",
#     "inferenceId": "63",
#     "inferenceTime": "2023-09-27T07:26:24Z"
#   },
#   "eventVersion": "0"
# }

# %% [markdown]
# #### 4.3 Generate synthetic ground truth
#
# Next, start generating ground truth data. The model quality job will fail if there's no ground truth data to merge.

# %%
import random


def ground_truth_with_id(inference_id):
    random.seed(inference_id)  # to get consistent results
    rand = random.random()
    return {
        "groundTruthData": {
            "data": "1" if rand < 0.7 else "0",  # randomly generate positive labels 70% of the time
            "encoding": "CSV",
        },
        "eventMetadata": {
            "eventId": str(inference_id),
        },
        "eventVersion": "0",
    }


def upload_ground_truth(records, upload_time):
    fake_records = [json.dumps(r) for r in records]
    data_to_upload = "\n".join(fake_records)
    target_s3_uri = f"{ground_truth_upload_path}/{upload_time:%Y/%m/%d/%H/%M%S}.jsonl"
    print(f"Uploading {len(fake_records)} records to", target_s3_uri)
    S3Uploader.upload_string_as_file_body(data_to_upload, target_s3_uri)

# %%
NUM_GROUND_TRUTH_RECORDS = 334  # 334 are the number of rows in data we're sending for inference


def generate_fake_ground_truth_forever():
    j = 0
    while True:
        fake_records = [ground_truth_with_id(i) for i in range(NUM_GROUND_TRUTH_RECORDS)]
        upload_ground_truth(fake_records, datetime.utcnow())
        j = (j + 1) % 5
        sleep(60 * 60)  # do this once an hour


gt_thread = Thread(target=generate_fake_ground_truth_forever)
gt_thread.start()
# Out:
# Uploading 334 records to s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/ground_truth_data/2023-09-27-06-31-29/2023/09/27/07/2822.jsonl
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# #### 4.4 Create a monitoring schedule
#
# Now that you have the baseline information and ground truth labels, create a monitoring schedule to run model quality monitoring job.

# %%
##Monitoring schedule name
churn_monitor_schedule_name = (
    f"DEMO-mlops-xgboost-monitoring-schedule-{datetime.utcnow():%Y-%m-%d-%H%M}"
)

# %% [markdown]
# For the monitoring schedule you need to specify how to interpret an endpoint's output. Given that the endpoint in this notebook outputs CSV data, the below code specifies that the first column of the output, `0`, contains a probability (of churn in this example). You will further specify `0.5` as the cutoff  used to determine a positive label (that is, predict that a customer will churn).

# %%
# Create an enpointInput
endpointInput = EndpointInput(
    endpoint_name=predictor.endpoint_name,
    probability_attribute="0",
    probability_threshold_attribute=0.5,
    destination="/opt/ml/processing/input_data",
)

# %%
# Create the monitoring schedule to execute every hour.
from sagemaker.model_monitor import CronExpressionGenerator

response = churn_model_quality_monitor.create_monitoring_schedule(
    monitor_schedule_name=churn_monitor_schedule_name,
    endpoint_input=endpointInput,
    output_s3_uri=baseline_results_uri,
    problem_type="MulticlassClassification",
    ground_truth_input=ground_truth_upload_path,
    constraints=baseline_job.suggested_constraints(),
    schedule_cron_expression=CronExpressionGenerator.hourly(),
    enable_cloudwatch_metrics=True,
)
# Out:
# ERROR:sagemaker.model_monitor.model_monitoring:It seems that this object was already used to create an Amazon Model Monitoring Schedule. To create another, first delete the existing one using my_monitor.delete_monitoring_schedule().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 4
#       1 # Create the monitoring schedule to execute every hour.
#       2 from sagemaker.model_monitor import CronExpressionGenerator
# ----> 4 response = churn_model_quality_monitor.create_monitoring_schedule(
#       5     monitor_schedule_name=churn_monitor_schedule_name,
#       6     endpoint_input=endpointInput,
#       7     output_s3_uri=baseline_results_uri,
#       8     problem_type="MulticlassClassification",
#       9     ground_truth_input=ground_truth_upload_path,
#      10     constraints=baseline_job.suggested_constraints(),
#      11     schedule_cron_expression=CronExpressionGenerator.hourly(),
#      12     enable_cloudwatch_metrics=True,
#      13 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model_monitor/model_monitoring.py:2972, in ModelQualityMonitor.create_monitoring_schedule(self, endpoint_input, ground_truth_input, problem_type, record_preprocessor_script, post_analytics_processor_script, output_s3_uri, constraints, monitor_schedule_name, schedule_cron_expression, enable_cloudwatch_metrics, batch_transform_input)
#    2966     message = (
#    2967         "It seems that this object was already used to create an Amazon Model "
#    2968         "Monitoring Schedule. To create another, first delete the existing one "
#    2969         "using my_monitor.delete_monitoring_schedule()."
#    2970     )
#    2971     _LOGGER.error(message)
# -> 2972     raise ValueError(message)
#    2974 if (batch_transform_input is not None) ^ (endpoint_input is None):
#    2975     message = (
#    2976         "Need to have either batch_transform_input or endpoint_input to create an "
#    2977         "Amazon Model Monitoring Schedule. "
#    2978         "Please provide only one of the above required inputs"
#    2979     )
#
# ValueError: It seems that this object was already used to create an Amazon Model Monitoring Schedule. To create another, first delete the existing one using my_monitor.delete_monitoring_schedule().

# %%
# Create the monitoring schedule
# You will see the monitoring schedule in the 'Scheduled' status
churn_model_quality_monitor.describe_schedule()
# Out:
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:ap-south-1:009676737623:monitoring-schedule/DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729',
#  'MonitoringScheduleName': 'DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729',
#  'MonitoringScheduleStatus': 'Scheduled',
#  'MonitoringType': 'ModelQuality',
#  'CreationTime': datetime.datetime(2023, 9, 27, 7, 29, 7, 280000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2023, 9, 27, 7, 29, 11, 137000, tzinfo=tzlocal()),
#  'MonitoringScheduleConfig': {'ScheduleConfig': {'ScheduleExpression': 'cron(0 * ? * * *)'},
#   'MonitoringJobDefinitionName': 'model-quality-job-definition-2023-09-27-07-29-06-881',
#   'MonitoringType': 'ModelQuality'},
#  'EndpointName': 'DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639',
#  'ResponseMetadata': {'RequestId': '85f79a37-f443-493e-9735-c1305e1d264b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '85f79a37-f443-493e-9735-c1305e1d264b',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '638',
#    'date': 'Wed, 27 Sep 2023 07:32:22 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### 4.5 Examine monitoring schedule executions

# %%
# Initially there will be no executions since the first execution happens at the top of the hour
# Note that it is common for the execution to luanch upto 20 min after the hour.
executions = churn_model_quality_monitor.list_executions()
executions
# Out:
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729
# []

# %%
# Wait for the first execution of the monitoring_schedule
print("Waiting for first execution", end="")
while True:
    execution = churn_model_quality_monitor.describe_schedule().get(
        "LastMonitoringExecutionSummary"
    )
    if execution:
        break
    print(".", end="", flush=True)
    sleep(10)
print()
print("Execution found!")
# Out:
# Waiting for first execution...................................................................................
# Execution found!

# %%
while not executions:
    executions = churn_model_quality_monitor.list_executions()
    sleep(10)
latest_execution = executions[-1]
latest_execution.describe()
# Out:
# {'ProcessingInputs': [{'InputName': 'constraints',
#    'AppManaged': False,
#    'S3Input': {'S3Uri': 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/results/constraints.json',
#     'LocalPath': '/opt/ml/processing/baseline/constraints',
#     'S3DataType': 'S3Prefix',
#     'S3InputMode': 'File',
#     'S3DataDistributionType': 'FullyReplicated'}},
#   {'InputName': 'endpoint_input_1',
#    'AppManaged': False,
#    'S3Input': {'S3Uri': 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/results/merge/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/AllTraffic/2023/09/27/07',
#     'LocalPath': '/opt/ml/processing/input_data/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/AllTraffic/2023/09/27/07',
#     'S3DataType': 'S3Prefix',
#     'S3InputMode': 'File',
#     'S3DataDistributionType': 'FullyReplicated',
#     'S3CompressionType': 'None'}}],
#  'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'result',
#     'S3Output': {'S3Uri': 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/results/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729/2023/09/27/08',
#      'LocalPath': '/opt/ml/processing/output',
#      'S3UploadMode': 'Continuous'},
#     'AppManaged': False}]},
#  'ProcessingJobName': 'model-quality-monitoring-202309270800-6da9465f864568bae85916f1',
#  'ProcessingResources': {'ClusterConfig': {'InstanceCount': 1,
#    'InstanceType': 'ml.m5.xlarge',
#    'VolumeSizeInGB': 20}},
#  'StoppingCondition': {'MaxRuntimeInSeconds': 1800},
#  'AppSpecification': {'ImageUri': '126357580389.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-model-monitor-analyzer'},
#  'Environment': {'analysis_type': 'MODEL_QUALITY',
#   'baseline_constraints': '/opt/ml/processing/baseline/constraints/constraints.json',
#   'dataset_format': '{"sagemakerMergeJson":{"captureIndexNames":["endpointOutput"]}}',
#   'dataset_source': '/opt/ml/processing/input_data',
#   'end_time': '2023-09-27T08:00:00Z',
#   'metric_time': '2023-09-27T07:00:00Z',
#   'monitoring_input_type': 'ENDPOINT_INPUT',
#   'output_path': '/opt/ml/processing/output',
#   'probability_attribute': '0',
#   'probability_threshold_attribute': '0.500000',
#   'problem_type': 'BinaryClassification',
#   'publish_cloudwatch_metrics': 'Enabled',
#   'sagemaker_endpoint_name': 'DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639',
#   'sagemaker_monitoring_schedule_name': 'DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729',
#   'start_time': '2023-09-27T07:00:00Z'},
#  'RoleArn': 'arn:aws:iam::009676737623:role/sagemaker-full-permission',
#  'ProcessingJobArn': 'arn:aws:sagemaker:ap-south-1:009676737623:processing-job/model-quality-monitoring-202309270800-6da9465f864568bae85916f1',
#  'ProcessingJobStatus': 'Completed',
#  'ExitMessage': 'Completed: Job completed successfully with no violations.',
#  'ProcessingEndTime': datetime.datetime(2023, 9, 27, 8, 15, 2, 921000, tzinfo=tzlocal()),
#  'ProcessingStartTime': datetime.datetime(2023, 9, 27, 8, 13, 14, 957000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2023, 9, 27, 8, 15, 3, 259000, tzinfo=tzlocal()),
#  'CreationTime': datetime.datetime(2023, 9, 27, 8, 9, 6, 462000, tzinfo=tzlocal()),
#  'MonitoringScheduleArn': 'arn:aws:sagemaker:ap-south-1:009676737623:monitoring-schedule/DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729',
#  'ResponseMetadata': {'RequestId': '0865ad5b-8de6-406b-9eeb-0092784d6724',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '0865ad5b-8de6-406b-9eeb-0092784d6724',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '2929',
#    'date': 'Wed, 27 Sep 2023 08:15:28 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ##### Inspect a specific execution (latest execution)
# In the previous cell, you picked up the latest completed or failed scheduled execution. Here are the possible terminal states and what each of them mean:
# * Completed - This means the monitoring execution completed and no issues were found in the violations report.
# * CompletedWithViolations - This means the execution completed, but constraint violations were detected.
# * Failed - The monitoring execution failed, maybe due to client error (perhaps incorrect role permissions) or infrastructure issues. Further examination of FailureReason and ExitMessage is necessary to identify what exactly happened.
# * Stopped - job exceeded max runtime or was manually stopped.

# %%
status = execution["MonitoringExecutionStatus"]

while status in ["Pending", "InProgress"]:
    print("Waiting for execution to finish", end="")
    latest_execution.wait(logs=False)
    latest_job = latest_execution.describe()
    print()
    print(f"{latest_job['ProcessingJobName']} job status:", latest_job["ProcessingJobStatus"])
    print(
        f"{latest_job['ProcessingJobName']} job exit message, if any:",
        latest_job.get("ExitMessage"),
    )
    print(
        f"{latest_job['ProcessingJobName']} job failure reason, if any:",
        latest_job.get("FailureReason"),
    )
    sleep(
        30
    )  # model quality executions consist of two Processing jobs, wait for second job to start
    latest_execution = churn_model_quality_monitor.list_executions()[-1]
    execution = churn_model_quality_monitor.describe_schedule()["LastMonitoringExecutionSummary"]
    status = execution["MonitoringExecutionStatus"]

print("Execution status is:", status)

if status != "Completed":
    print(execution)
    print(
        "====STOP==== \n No completed executions to inspect further. Please wait till an execution completes or investigate previously reported failures."
    )
# Out:
# Waiting for execution to finish!
# model-quality-monitoring-202309270800-6da9465f864568bae85916f1 job status: Completed
# model-quality-monitoring-202309270800-6da9465f864568bae85916f1 job exit message, if any: Completed: Job completed successfully with no violations.
# model-quality-monitoring-202309270800-6da9465f864568bae85916f1 job failure reason, if any: None
# Execution status is: Completed

# %%
latest_execution = churn_model_quality_monitor.list_executions()[-1]
report_uri = latest_execution.describe()["ProcessingOutputConfig"]["Outputs"][0]["S3Output"][
    "S3Uri"
]
print("Report Uri:", report_uri)
# Out:
# Report Uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baselining/results/DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639/DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729/2023/09/27/08

# %% [markdown]
# #### 4.5 View violations generated by monitoring schedule

# %% [markdown]
# If there are any violations compared to the baseline, they will be listed in the reports uploaded to S3.

# %%
pd.options.display.max_colwidth = None
violations = latest_execution.constraint_violations().body_dict["violations"]
violations_df = pd.json_normalize(violations)
violations_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Here you can see that one of the violations generated is that the f2 score is less than the threshold value set as part of baselining.

# %% [markdown]
# ## Section 5 - Analyze model quality CloudWatch metrics <a id='analyze-cloudwatch-metrics'></a>
#
# In addition to the violations, the monitoring schedule also emits CloudWatch metrics. In this section, you will view the metrics generated and setup an CloudWatch alarm to be triggered when the model quality drifts from the baseline thresholds. You could use CloudWatch alarms to trigger remedial actions such as retraining your model or updating the training dataset.

# %% [markdown]
# #### 5.1 List the CW metrics generated.

# %%
# Create CloudWatch client
cw_client = boto3.Session().client("cloudwatch")

namespace = "aws/sagemaker/Endpoints/model-metrics"

cw_dimensions = [
    {"Name": "Endpoint", "Value": endpoint_name},
    {"Name": "MonitoringSchedule", "Value": churn_monitor_schedule_name},
]
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
# List metrics through the pagination interface
paginator = cw_client.get_paginator("list_metrics")

for response in paginator.paginate(Dimensions=cw_dimensions, Namespace=namespace):
    model_quality_metrics = response["Metrics"]
    for metric in model_quality_metrics:
        print(metric["MetricName"])
# Out:
# accuracy_best_constant_classifier
# au_prc
# f0_5
# f2
# f0_5_best_constant_classifier
# true_negative_rate
# false_positive_rate
# false_negative_rate
# precision
# auc
# true_positive_rate
# f1
# f2_best_constant_classifier
# f1_best_constant_classifier
# precision_best_constant_classifier
# accuracy
# total_number_of_violations
# recall
# recall_best_constant_classifier

# %% [markdown]
# #### 5.2 Create a CloudWatch Alarm
#
# Based on the cloud watch metrics, you can create a cloud watch alarm when a specific metric does not meet the threshold configured. Here you will create an alarm if the f2 value of the model fall below the threshold suggested by the baseline constraints.

# %%
alarm_name = "MODEL_QUALITY_F2_SCORE"
alarm_desc = (
    "Trigger an CloudWatch alarm when the f2 score drifts away from the baseline constraints"
)
mdoel_quality_f2_drift_threshold = (
    0.625  ##Setting this threshold purposefully low to see the alarm quickly.
)
metric_name = "f2"
namespace = "aws/sagemaker/Endpoints/model-metrics"

cw_client.put_metric_alarm(
    AlarmName=alarm_name,
    AlarmDescription=alarm_desc,
    ActionsEnabled=True,
    MetricName=metric_name,
    Namespace=namespace,
    Statistic="Average",
    Dimensions=[
        {"Name": "Endpoint", "Value": endpoint_name},
        {"Name": "MonitoringSchedule", "Value": churn_monitor_schedule_name},
    ],
    Period=600,
    EvaluationPeriods=1,
    DatapointsToAlarm=1,
    Threshold=mdoel_quality_f2_drift_threshold,
    ComparisonOperator="LessThanOrEqualToThreshold",
    TreatMissingData="breaching",
)
# Out:
# hihi
# hi
#
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# {'ResponseMetadata': {'RequestId': '8c5ec9c2-5bb5-41f7-80d7-1c84f392406c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8c5ec9c2-5bb5-41f7-80d7-1c84f392406c',
#    'content-type': 'text/xml',
#    'content-length': '214',
#    'date': 'Wed, 27 Sep 2023 08:43:27 GMT'},
#   'RetryAttempts': 0}}
# hihi
#
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# errohi
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hihi
#
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hihi
# hi
# error
#
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hihi
#
# hi
# hi
# error
# errohi
# hi
# error
#
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hihi
# hi
#
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erroerror
# hi
# hi
#
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# errorhi
#
# hi
# hi
# erro
# error
# hi
# hierror
# hi
# hi
# hi
# hi
# hi
#
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# errorhi
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hihi
# hi
# hi
#
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# errorerro
# hi
# hi
# hi
#
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erroerror
#
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# errorhi
# error
#
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erroerror
#
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# errohi
#
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# errorhi
# hi
# hi
# hi
#
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erroerror
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hihi
# hi
# hi
# hi
# hi
# hi
#
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hierro
# hi
# hi
#
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hihi
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
# error
#
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hihi
# hi
# error
# hi
# hi
# erro
#
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# erro
# hihi
# hi
# hi
#
# erro
# hi
# hi
# error
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hihi
#
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hihi
#
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hihi
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# errohi
# hi
# hi
#
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hihi
# hi
#
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hierro
# hi
#
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hihi
# hi
#
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# errorhi
# hi
# hi
# error
# hi
# hi
# hi
# hi
#
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hihi
#
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hihi
#
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hierro
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hihi
# hi
# hi
# hi
# hi
#
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# errorerro
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
#
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hihi
#
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# error
# hi
# hi
# hi
#
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# errohi
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
#
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erroerror
# hi
#
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hihi
# hi
# error
# erro
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hihi
#
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# error
# hi
# hi
#
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hihi
# hi
#
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hierro
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hierror
#
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hierror
# hi
# hi
# hi
#
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# errorhi
# error
# hi
# hi
# hi
#
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hihi
#
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hihi
#
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erroerror
# hi
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# errorhi
# hi
#
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hierror
# hi
# hi
#
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# errohi
#
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hihi
# hi
# hi
# hi
#
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
#
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hihi
# error
#
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hihi
# erro
#
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# errorhi
#
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hihi
# hi
# hi
# hi
# hi
#
# hi
# erro
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hihi
#
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hihi
# hi
#
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# errorhi
# erro
#
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hihi
# error
#
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hihi
#
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hihi
#
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hihi
#
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hihi
#
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hihi
#
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hihi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
#
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# errohi
# hi
#
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# errohi
#
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# erro
# errorhi
# hi
# hi
#
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
# erro
#
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hierror
# error
#
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hihi
#
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hierro
#
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# error
# hi
# hi
# hi
# errohi
# hi
# error
# hi
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hihi
# hi
#
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# errorhi
# error
# hi
# erro
# hi
#
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro

# %% [markdown]
# #### 5.3 Validation
# In a few minutes, you should see a CloudWatch alarm created. The alarm will first be in "Insufficient Data" state and moves into "Alert" state. This can be verified in the CloudWatch console

# %% [markdown]
# <IMG src=images/CW_ALARM_Model_Quality_1.png/>

# %% [markdown]
# <IMG src=images/CW_ALARM_Model_Quality_2.png/>

# %% [markdown]
# Once the CW Alarm is generated, you can decide on what actions you want to take on these alerts.  A possible action could be updating the training data an retraining the model

# %% [markdown]
# ## Clean up <a id='cleanup'></a>

# %% [markdown]
# You can keep your endpoint running to continue capturing data. If you do not plan to collect more data or use this endpoint further, you should delete the endpoint to avoid incurring additional charges. Note that deleting your endpoint does not delete the data that was captured during the model invocations. That data persists in Amazon S3 until you delete it yourself.
#
# But before that, you need to delete the schedule first.

# %%
churn_model_quality_monitor.delete_monitoring_schedule()
sleep(60)  # actually wait for the deletion
# Out:
# Deleting Monitoring Schedule with name: DEMO-mlops-xgboost-monitoring-schedule-2023-09-27-0729
# INFO:sagemaker.model_monitor.model_monitoring:Deleting Model Quality Job Definition with name: model-quality-job-definition-2023-09-27-07-29-06-881

# %%
predictor.delete_model()
predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting model with name: sagemaker-xgboost-2023-09-27-06-39-02-896
# INFO:sagemaker:Deleting endpoint configuration with name: DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639
# INFO:sagemaker:Deleting endpoint with name: DEMO-mlops-xgboost-quality-monitor-2023-09-27-0639
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hihi
# erro
#
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# errorerror
# hi
# hi
# hi
# hi
#
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hierro
# hi
# hi
# erro
#
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# error
# hi
# hi
#
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hihi
#
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hierror
# hi
#
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hihi
# hi
# hi
# hi
#
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hihi
#
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hihi
# error
# hi
# erro
# hi
# hi
#
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# errohi
#
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hierro
#
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# errohi
# hi
# hi
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# error
# hi
#
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erroerror
#
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hihi
#
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# errorhi
# hi
#
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# errorhi
# hi
# hi
# error
#
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hierro
# hi
# error
#
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hihi
# erro
# error
#
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hihi
# hi
# error
# hi
#
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# erroerror
# hi
#
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hierror
# hi
# hi
#
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# errohi
# hi
# error
# hi
#
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
#
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hihi
# hi
# error
# hi
# hi
# hi
# hi
#
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hihi
# hi
#
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hihi
#
# hi
# hi
# erro
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hierror
# hi
# error
# hi
#
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hihi
#
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hihi
# hi
# erro
#
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# errohi
#
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hihi
# hi
#
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hierror
# hi
# hi
# hi
#
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hihi
#
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hihi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
#
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# errorhi
# erro
#
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# ...
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# errorhi
#
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erroerror
#
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hierro
#
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hihi
#
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hihi
#
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hihi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
#
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hihi
# error
#
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hihi
# error
# hi
# hi
# hi
# error
# hi
# error
# hi
#
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hihi
# hi
# hi
# hi
# error
# hi
#
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erroerror
# error
#
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# errorerro
#
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# error
# hihi
#
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hihi
# hi
# hi
#
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hihi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
#
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# errohi
# hi
# error
# hi
# hi
#
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hihi
# hi
# error
# erro
#
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hihi
# hi
#
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hierror
#
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hierror
#
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hierro
# hi
#
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hierror
#
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hihi
# hi
# hi
# erro
# error
# hi
# hi
#
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hihi
# erro
#
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hihi
#
# erro
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# error
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# error
# errohi
# hi
# hi
# hi
# error
# hi
# hi
# hi
#
# hi
# hi
# error
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# error
# error
# erro
# hi
# hi
# hi
# hi
# error
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# error
# error
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# hi
# error
# hi
# error
# hi
# hi
# hi
# erro
# hi
# hi
# hi
# error
# hi
# hi
# hi
# error
# erro
# hi
# hi
# hi
# hi
# hi
# hi
# error
# hi
# error
# hi
# hi
# erro
# hi
# hi
# hi
# hi
# hi
# erro
# hi
# error
# hi
# hi
# hi
# hi
# hi
# hi
# error
# erro
# hi
# hi

# %% [markdown]
# ## Notebook CI Test Results
#
# This notebook was tested in multiple regions. The test results are as follows, except for us-west-2 which is shown at the top of the notebook.
#
# ![This us-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/us-east-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This us-east-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/us-east-2/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This us-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/us-west-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ca-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ca-central-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This sa-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/sa-east-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This eu-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/eu-west-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This eu-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/eu-west-2/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This eu-west-3 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/eu-west-3/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This eu-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/eu-central-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This eu-north-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/eu-north-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ap-southeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ap-southeast-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ap-southeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ap-southeast-2/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ap-northeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ap-northeast-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ap-northeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ap-northeast-2/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
#
# ![This ap-south-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://h75twx4l60.execute-api.us-west-2.amazonaws.com/sagemaker-nb/ap-south-1/sagemaker_model_monitor|model_quality|model_quality_churn_sdk.ipynb)
