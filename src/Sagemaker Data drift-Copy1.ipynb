# %%
# Importing the necessary library
import boto3
import sagemaker
import pandas as pd
from joblib import dump, load
import s3fs

# %%
# Initialising new sagemaker session as "sess".
sess = sagemaker.Session()
# Bucket variable is used for storing the location of the bucket
bucket = 'sagemaker-studio-009676737623-l4vs7j0o0ib'
# Assigning the prefix variable 
prefix = 'mlops-level1-data' 
# Check for necessary permission needed for training and deploying models. 
role = sagemaker.get_execution_role()
# To understand where this session is configured to operate.
region = boto3.Session().region_name

# %%
training_data_path = "s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baseline/data/training-inputs-with-header.csv"

# %% [markdown]
# ## Model Baseline

# %%
from sagemaker.inputs import BatchDataCaptureConfig

# %%
# copy over the training dataset to Amazon S3 (if you already have it in Amazon S3, you could reuse it)
baseline_prefix = prefix + "/baseline"
baseline_data_prefix = baseline_prefix + "/data"
baseline_results_prefix = baseline_prefix + "/results"

baseline_data_uri = "s3://{}/{}".format(bucket, baseline_data_prefix)
baseline_results_uri = "s3://{}/{}".format(bucket, baseline_results_prefix)
print("Baseline data uri: {}".format(baseline_data_uri))
print("Baseline results uri: {}".format(baseline_results_uri))
# Out:
# Baseline data uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baseline/data
# Baseline results uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baseline/results

# %%
from sagemaker.model_monitor import DefaultModelMonitor
from sagemaker.model_monitor.dataset_format import DatasetFormat

my_default_monitor = DefaultModelMonitor(
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    volume_size_in_gb=20,
    max_runtime_in_seconds=3600,
)

my_default_monitor.suggest_baseline(
    baseline_dataset=training_data_path,
    dataset_format=DatasetFormat.csv(header=True),
    output_s3_uri=baseline_results_uri,
    wait=True,
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: .
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:sagemaker:Creating processing-job with name baseline-suggestion-job-2023-09-23-17-33-24-535
# ........................2023-09-23 17:37:16.177731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-09-23 17:37:16.177769: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-09-23 17:37:17.698900: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-09-23 17:37:17.698930: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-09-23 17:37:17.698950: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-10-0-153-182.ap-south-1.compute.internal): /proc/driver/nvidia/version does not exist
# 2023-09-23 17:37:17.699204: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 17:37:19,235 - __main__ - INFO - All params:{'ProcessingJobArn': 'arn:aws:sagemaker:ap-south-1:009676737623:processing-job/baseline-suggestion-job-2023-09-23-17-33-24-535', 'ProcessingJobName': 'baseline-suggestion-job-2023-09-23-17-33-24-535', 'Environment': {'dataset_format': '{"csv": {"header": true, "output_columns_position": "START"}}', 'dataset_source': '/opt/ml/processing/input/baseline_dataset_input', 'output_path': '/opt/ml/processing/output', 'publish_cloudwatch_metrics': 'Disabled'}, 'AppSpecification': {'ImageUri': '126357580389.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-model-monitor-analyzer', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'baseline_dataset_input', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/baseline_dataset_input', 'S3Uri': 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baseline/data/training-inputs-with-header.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'monitoring_output', 'AppManaged': False, 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/baseline/results', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 1, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 20, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::009676737623:role/sagemaker-full-permission', 'StoppingCondition': {'MaxRuntimeInSeconds': 3600}}
# 2023-09-23 17:37:19,235 - __main__ - INFO - Current Environment:{'dataset_format': '{"csv": {"header": true, "output_columns_position": "START"}}', 'dataset_source': '/opt/ml/processing/input/baseline_dataset_input', 'output_path': '/opt/ml/processing/output', 'publish_cloudwatch_metrics': 'Disabled'}
# 2023-09-23 17:37:19,235 - __main__ - INFO - categorical_drift_method:None
# 2023-09-23 17:37:19,235 - DefaultDataAnalyzer - INFO - Performing analysis with input: {"dataset_source": "/opt/ml/processing/input/baseline_dataset_input", "dataset_format": {"csv": {"header": true, "output_columns_position": "START"}}, "output_path": "/opt/ml/processing/output", "monitoring_input_type": null, "analysis_type": null, "problem_type": null, "inference_attribute": null, "probability_attribute": null, "ground_truth_attribute": null, "probability_threshold_attribute": null, "positive_label": null, "exclude_features_attribute": null, "record_preprocessor_script": null, "post_analytics_processor_script": null, "baseline_constraints": null, "baseline_statistics": null, "data_quality_monitoring_config": {"evaluate_constraints": "Enabled", "emit_metrics": "Enabled", "datatype_check_threshold": 1.0, "domain_content_threshold": 1.0, "distribution_constraints": {"perform_comparison": "Enabled", "comparison_threshold": 0.1, "comparison_method": "Robust", "categorical_comparison_threshold": 0.1, "categorical_drift_method": "LInfinity"}}, "start_time": null, "end_time": null, "metric_time": null, "cloudwatch_metrics_directory": "/opt/ml/output/metrics/cloudwatch", "publish_cloudwatch_metrics": "Disabled", "sagemaker_endpoint_name": null, "sagemaker_monitoring_schedule_name": null, "output_message_file": "/opt/ml/output/message", "detect_outliers": null, "detect_drift": null, "image_data": null, "report_enabled": false, "auto_ml_job_detail": null}
# 2023-09-23 17:37:19,235 - DefaultDataAnalyzer - INFO - Bootstrapping yarn
# 2023-09-23 17:37:19,235 - bootstrap - INFO - Copy aws jars
# 2023-09-23 17:37:19,291 - bootstrap - INFO - Copy cluster config
# 2023-09-23 17:37:19,292 - bootstrap - INFO - Write runtime cluster config
# 2023-09-23 17:37:19,292 - bootstrap - INFO - Resource Config is: {'current_host': 'algo-1', 'hosts': ['algo-1']}
# 2023-09-23 17:37:19,301 - bootstrap - INFO - Finished Yarn configuration files setup.
# 2023-09-23 17:37:19,301 - bootstrap - INFO - Starting spark process for master node algo-1
# 2023-09-23 17:37:19,301 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs namenode -format -force
# WARNING: /usr/hadoop-3.0.0/logs does not exist. Creating.
# 2023-09-23 17:37:19,770 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = algo-1/10.0.153.182
# STARTUP_MSG:   args = [-format, -force]
# STARTUP_MSG:   version = 3.0.0
# STARTUP_MSG:   classpath = /usr/hadoop-3.0.0/etc/hadoop:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-lang-2.6.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-collections-3.2.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/nimbus-jose-jwt-4.41.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/re2j-1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-xc-1.9.13.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-compress-1.4.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-core-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jaxb-api-2.2.11.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-mapper-asl-1.9.13.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-simplekdc-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/gson-2.2.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/log4j-1.2.17.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/stax2-api-3.1.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/accessors-smart-1.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-util-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jersey-servlet-1.19.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/junit-4.11.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/asm-5.0.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-net-3.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-util-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/metrics-core-3.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-common-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-security-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/token-provider-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jaxb-impl-2.2.3-1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-core-2.7.8.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-identity-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-xml-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsch-0.1.54.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-math3-3.1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-asn1-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsp-api-2.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-lang3-3.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/hadoop-annotations-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/guava-11.0.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/htrace-core4-4.1.0-incubating.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-webapp-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/httpclient-4.5.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-http-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/zookeeper-3.4.9.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/httpcore-4.4.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/avro-1.7.7.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/protobuf-java-2.5.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/paranamer-2.3.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-beanutils-1.9.3.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/hadoop-auth-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/netty-3.10.5.Final.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-config-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/woodstox-core-5.0.3.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/xz-1.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jersey-core-1.19.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/mockito-all-1.8.5.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-server-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-io-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-util-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common ...
# n-common-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-applications-unmanaged-am-launcher-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-resourcemanager-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-timelineservice-hbase-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-common-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-tests-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-nodemanager-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-applicationhistoryservice-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-web-proxy-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-applications-distributedshell-3.0.0.jar
# STARTUP_MSG:   build = https://git-wip-us.apache.org/repos/asf/hadoop.git -r c25427ceca461ee979d30edd7a4b0f50718e6533; compiled by 'andrew' on 2017-12-08T19:16Z
# STARTUP_MSG:   java = 1.8.0_382
# ************************************************************/
# 2023-09-23 17:37:19,777 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2023-09-23 17:37:19,780 INFO namenode.NameNode: createNameNode [-format, -force]
# Formatting using clusterid: CID-862fc5fb-7e4e-4569-b59a-b95d69bcf70f
# 2023-09-23 17:37:20,264 INFO namenode.FSEditLog: Edit logging is async:true
# 2023-09-23 17:37:20,274 INFO namenode.FSNamesystem: KeyProvider: null
# 2023-09-23 17:37:20,275 INFO namenode.FSNamesystem: fsLock is fair: true
# 2023-09-23 17:37:20,278 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2023-09-23 17:37:20,283 INFO namenode.FSNamesystem: fsOwner             = root (auth:SIMPLE)
# 2023-09-23 17:37:20,284 INFO namenode.FSNamesystem: supergroup          = supergroup
# 2023-09-23 17:37:20,284 INFO namenode.FSNamesystem: isPermissionEnabled = true
# 2023-09-23 17:37:20,284 INFO namenode.FSNamesystem: HA Enabled: false
# 2023-09-23 17:37:20,313 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2023-09-23 17:37:20,323 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit: configured=1000, counted=60, effected=1000
# 2023-09-23 17:37:20,323 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2023-09-23 17:37:20,326 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2023-09-23 17:37:20,329 INFO blockmanagement.BlockManager: The block deletion will start around 2023 Sep 23 17:37:20
# 2023-09-23 17:37:20,331 INFO util.GSet: Computing capacity for map BlocksMap
# 2023-09-23 17:37:20,331 INFO util.GSet: VM type       = 64-bit
# 2023-09-23 17:37:20,332 INFO util.GSet: 2.0% max memory 3.1 GB = 62.9 MB
# 2023-09-23 17:37:20,332 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2023-09-23 17:37:20,399 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2023-09-23 17:37:20,403 INFO Configuration.deprecation: No unit for dfs.namenode.safemode.extension(30000) assuming MILLISECONDS
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.9990000128746033
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: minReplication             = 1
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2023-09-23 17:37:20,403 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2023-09-23 17:37:20,429 INFO util.GSet: Computing capacity for map INodeMap
# 2023-09-23 17:37:20,429 INFO util.GSet: VM type       = 64-bit
# 2023-09-23 17:37:20,429 INFO util.GSet: 1.0% max memory 3.1 GB = 31.4 MB
# 2023-09-23 17:37:20,429 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2023-09-23 17:37:20,431 INFO namenode.FSDirectory: ACLs enabled? false
# 2023-09-23 17:37:20,431 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2023-09-23 17:37:20,431 INFO namenode.FSDirectory: XAttrs enabled? true
# 2023-09-23 17:37:20,431 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2023-09-23 17:37:20,435 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true
# 2023-09-23 17:37:20,438 INFO util.GSet: Computing capacity for map cachedBlocks
# 2023-09-23 17:37:20,438 INFO util.GSet: VM type       = 64-bit
# 2023-09-23 17:37:20,439 INFO util.GSet: 0.25% max memory 3.1 GB = 7.9 MB
# 2023-09-23 17:37:20,439 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2023-09-23 17:37:20,445 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2023-09-23 17:37:20,445 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2023-09-23 17:37:20,445 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2023-09-23 17:37:20,448 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2023-09-23 17:37:20,448 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2023-09-23 17:37:20,449 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2023-09-23 17:37:20,449 INFO util.GSet: VM type       = 64-bit
# 2023-09-23 17:37:20,449 INFO util.GSet: 0.029999999329447746% max memory 3.1 GB = 966.1 KB
# 2023-09-23 17:37:20,449 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2023-09-23 17:37:20,470 INFO namenode.FSImage: Allocated new BlockPoolId: BP-1808953170-10.0.153.182-1695490640464
# 2023-09-23 17:37:20,480 INFO common.Storage: Storage directory /opt/amazon/hadoop/hdfs/namenode has been successfully formatted.
# 2023-09-23 17:37:20,487 INFO namenode.FSImageFormatProtobuf: Saving image file /opt/amazon/hadoop/hdfs/namenode/current/fsimage.ckpt_0000000000000000000 using no compression
# 2023-09-23 17:37:20,561 INFO namenode.FSImageFormatProtobuf: Image file /opt/amazon/hadoop/hdfs/namenode/current/fsimage.ckpt_0000000000000000000 of size 386 bytes saved in 0 seconds.
# 2023-09-23 17:37:20,573 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2023-09-23 17:37:20,590 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at algo-1/10.0.153.182
# ************************************************************/
# 2023-09-23 17:37:20,599 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs --daemon start namenode
# 2023-09-23 17:37:22,660 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/hdfs --daemon start namenode, return code 1
# 2023-09-23 17:37:22,660 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs --daemon start datanode
# 2023-09-23 17:37:24,731 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/hdfs --daemon start datanode, return code 1
# 2023-09-23 17:37:24,732 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start resourcemanager
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /var/log/yarn/ does not exist. Creating.
# 2023-09-23 17:37:26,862 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start resourcemanager, return code 1
# 2023-09-23 17:37:26,862 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start nodemanager
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# 2023-09-23 17:37:28,961 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start nodemanager, return code 1
# 2023-09-23 17:37:28,961 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start proxyserver
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# 2023-09-23 17:37:31,125 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start proxyserver, return code 1
# 2023-09-23 17:37:31,125 - DefaultDataAnalyzer - INFO - Total number of hosts in the cluster: 1
# 2023-09-23 17:37:41,127 - DefaultDataAnalyzer - INFO - Running command: bin/spark-submit --master yarn --deploy-mode client --conf spark.hadoop.fs.s3a.aws.credentials.provider=org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider --conf spark.serializer=org.apache.spark.serializer.KryoSerializer /opt/amazon/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar --analytics_input /tmp/spark_job_config.json
# 2023-09-23 17:37:42,663 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2023-09-23 17:37:43,051 INFO Main: Start analyzing with args: --analytics_input /tmp/spark_job_config.json
# 2023-09-23 17:37:43,085 INFO Main: Analytics input path: DataAnalyzerParams(/tmp/spark_job_config.json,yarn)
# 2023-09-23 17:37:43,098 INFO FileUtil: Read file from path /tmp/spark_job_config.json.
# 2023-09-23 17:37:43,627 INFO spark.SparkContext: Running Spark version 3.3.0
# 2023-09-23 17:37:43,651 INFO resource.ResourceUtils: ==============================================================
# 2023-09-23 17:37:43,651 INFO resource.ResourceUtils: No custom resources configured for spark.driver.
# 2023-09-23 17:37:43,651 INFO resource.ResourceUtils: ==============================================================
# 2023-09-23 17:37:43,652 INFO spark.SparkContext: Submitted application: SageMakerDataAnalyzer
# 2023-09-23 17:37:43,681 INFO resource.ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 3, script: , vendor: , memory -> name: memory, amount: 11412, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 2023-09-23 17:37:43,696 INFO resource.ResourceProfile: Limiting resource is cpus at 3 tasks per executor
# 2023-09-23 17:37:43,698 INFO resource.ResourceProfileManager: Added ResourceProfile id: 0
# 2023-09-23 17:37:43,747 INFO spark.SecurityManager: Changing view acls to: root
# 2023-09-23 17:37:43,747 INFO spark.SecurityManager: Changing modify acls to: root
# 2023-09-23 17:37:43,747 INFO spark.SecurityManager: Changing view acls groups to:
# 2023-09-23 17:37:43,748 INFO spark.SecurityManager: Changing modify acls groups to:
# 2023-09-23 17:37:43,748 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 2023-09-23 17:37:44,124 INFO util.Utils: Successfully started service 'sparkDriver' on port 34287.
# 2023-09-23 17:37:44,152 INFO spark.SparkEnv: Registering MapOutputTracker
# 2023-09-23 17:37:44,187 INFO spark.SparkEnv: Registering BlockManagerMaster
# 2023-09-23 17:37:44,205 INFO storage.BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 2023-09-23 17:37:44,206 INFO storage.BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 2023-09-23 17:37:44,236 INFO spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 2023-09-23 17:37:44,257 INFO storage.DiskBlockManager: Created local directory at /tmp/blockmgr-19058915-b027-4b9d-a37f-ea70437240eb
# 2023-09-23 17:37:44,276 INFO memory.MemoryStore: MemoryStore started with capacity 1458.6 MiB
# 2023-09-23 17:37:44,325 INFO spark.SparkEnv: Registering OutputCommitCoordinator
# 2023-09-23 17:37:44,367 INFO spark.SparkContext: Added JAR file:/opt/amazon/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar at spark://10.0.153.182:34287/jars/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar with timestamp 1695490663622
# 2023-09-23 17:37:44,852 INFO client.RMProxy: Connecting to ResourceManager at /10.0.153.182:8032
# 2023-09-23 17:37:45,517 INFO conf.Configuration: resource-types.xml not found
# 2023-09-23 17:37:45,517 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2023-09-23 17:37:45,523 INFO yarn.Client: Verifying our application has not requested more than the maximum memory capability of the cluster (15563 MB per container)
# 2023-09-23 17:37:45,523 INFO yarn.Client: Will allocate AM container, with 896 MB memory including 384 MB overhead
# 2023-09-23 17:37:45,524 INFO yarn.Client: Setting up container launch context for our AM
# 2023-09-23 17:37:45,524 INFO yarn.Client: Setting up the launch environment for our AM container
# 2023-09-23 17:37:45,530 INFO yarn.Client: Preparing resources for our AM container
# 2023-09-23 17:37:45,611 WARN yarn.Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2023-09-23 17:37:47,381 INFO yarn.Client: Uploading resource file:/tmp/spark-6c553921-3e48-474a-9e09-fd2be8b0638d/__spark_libs__7338305374428395793.zip -> hdfs://10.0.153.182/user/root/.sparkStaging/application_1695490646464_0001/__spark_libs__7338305374428395793.zip
# 2023-09-23 17:37:49,676 INFO yarn.Client: Uploading resource file:/tmp/spark-6c553921-3e48-474a-9e09-fd2be8b0638d/__spark_conf__5338897149118012157.zip -> hdfs://10.0.153.182/user/root/.sparkStaging/application_1695490646464_0001/__spark_conf__.zip
# 2023-09-23 17:37:49,725 INFO spark.SecurityManager: Changing view acls to: root
# 2023-09-23 17:37:49,726 INFO spark.SecurityManager: Changing modify acls to: root
# 2023-09-23 17:37:49,726 INFO spark.SecurityManager: Changing view acls groups to:
# 2023-09-23 17:37:49,726 INFO spark.SecurityManager: Changing modify acls groups to:
# 2023-09-23 17:37:49,727 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 2023-09-23 17:37:49,755 INFO yarn.Client: Submitting application application_1695490646464_0001 to ResourceManager
# 2023-09-23 17:37:49,942 INFO impl.YarnClientImpl: Submitted application application_1695490646464_0001
# 2023-09-23 17:37:50,952 INFO yarn.Client: Application report for application_1695490646464_0001 (state: ACCEPTED)
# 2023-09-23 17:37:50,955 INFO yarn.Client:
# #011 client token: N/A
# #011 diagnostics: [Sat Sep 23 17:37:50 +0000 2023] Scheduler has assigned a container for AM, waiting for AM container to be launched
# #011 ApplicationMaster host: N/A
# #011 ApplicationMaster RPC port: -1
# #011 queue: default
# #011 start time: 1695490669845
# #011 final status: UNDEFINED
# #011 tracking URL: http://algo-1:8088/proxy/application_1695490646464_0001/
# #011 user: root
# 2023-09-23 17:37:51,958 INFO yarn.Client: Application report for application_1695490646464_0001 (state: ACCEPTED)
# 2023-09-23 17:37:52,961 INFO yarn.Client: Application report for application_1695490646464_0001 (state: ACCEPTED)
# 2023-09-23 17:37:53,964 INFO yarn.Client: Application report for application_1695490646464_0001 (state: ACCEPTED)
# 2023-09-23 17:37:54,967 INFO yarn.Client: Application report for application_1695490646464_0001 (state: ACCEPTED)
# 2023-09-23 17:37:55,282 INFO cluster.YarnClientSchedulerBackend: Add WebUI Filter. org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter, Map(PROXY_HOSTS -> algo-1, PROXY_URI_BASES -> http://algo-1:8088/proxy/application_1695490646464_0001), /proxy/application_1695490646464_0001
# 2023-09-23 17:37:55,975 INFO yarn.Client: Application report for application_1695490646464_0001 (state: RUNNING)
# 2023-09-23 17:37:55,977 INFO yarn.Client:
# #011 client token: N/A
# #011 diagnostics: N/A
# #011 ApplicationMaster host: 10.0.153.182
# #011 ApplicationMaster RPC port: -1
# #011 queue: default
# #011 start time: 1695490669845
# #011 final status: UNDEFINED
# #011 tracking URL: http://algo-1:8088/proxy/application_1695490646464_0001/
# #011 user: root
# 2023-09-23 17:37:55,981 INFO cluster.YarnClientSchedulerBackend: Application application_1695490646464_0001 has started running.
# 2023-09-23 17:37:56,004 INFO util.Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 43091.
# 2023-09-23 17:37:56,004 INFO netty.NettyBlockTransferService: Server created on 10.0.153.182:43091
# 2023-09-23 17:37:56,006 INFO storage.BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 2023-09-23 17:37:56,015 INFO storage.BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.153.182, 43091, None)
# 2023-09-23 17:37:56,019 INFO storage.BlockManagerMasterEndpoint: Registering block manager 10.0.153.182:43091 with 1458.6 MiB RAM, BlockManagerId(driver, 10.0.153.182, 43091, None)
# 2023-09-23 17:37:56,022 INFO storage.BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.153.182, 43091, None)
# 2023-09-23 17:37:56,024 INFO storage.BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.153.182, 43091, None)
# 2023-09-23 17:37:56,182 INFO util.log: Logging initialized @14906ms to org.sparkproject.jetty.util.log.Slf4jLog
# 2023-09-23 17:37:56,792 INFO cluster.YarnSchedulerBackend$YarnSchedulerEndpoint: ApplicationMaster registered as NettyRpcEndpointRef(spark-client://YarnAM)
# 2023-09-23 17:38:01,021 INFO cluster.YarnSchedulerBackend$YarnDriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.0.153.182:47044) with ID 1,  ResourceProfileId 0
# 2023-09-23 17:38:01,223 INFO storage.BlockManagerMasterEndpoint: Registering block manager algo-1:43953 with 5.8 GiB RAM, BlockManagerId(1, algo-1, 43953, None)
# 2023-09-23 17:38:14,817 INFO cluster.YarnClientSchedulerBackend: SchedulerBackend is ready for scheduling beginning after waiting maxRegisteredResourcesWaitingTime: 30000000000(ns)
# 2023-09-23 17:38:14,986 WARN spark.SparkContext: Spark is not running in local mode, therefore the checkpoint directory must not be on the local filesystem. Directory '/tmp' appears to be on the local filesystem.
# 2023-09-23 17:38:15,044 INFO internal.SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 2023-09-23 17:38:15,050 INFO internal.SharedState: Warehouse path is 'file:/usr/spark-3.3.0/spark-warehouse'.
# 2023-09-23 17:38:16,066 INFO datasources.InMemoryFileIndex: It took 45 ms to list leaf files for 1 paths.
# 2023-09-23 17:38:16,267 INFO memory.MemoryStore: Block broadcast_0 stored as values in memory (estimated size 416.9 KiB, free 1458.2 MiB)
# 2023-09-23 17:38:16,578 INFO memory.MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 39.2 KiB, free 1458.2 MiB)
# 2023-09-23 17:38:16,581 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.0.153.182:43091 (size: 39.2 KiB, free: 1458.6 MiB)
# 2023-09-23 17:38:16,585 INFO spark.SparkContext: Created broadcast 0 from csv at DatasetReader.scala:99
# 2023-09-23 17:38:16,959 INFO input.FileInputFormat: Total input files to process : 1
# 2023-09-23 17:38:16,965 INFO input.FileInputFormat: Total input files to process : 1
# 2023-09-23 17:38:16,974 INFO input.CombineFileInputFormat: DEBUG: Terminated node allocation with : CompletedNodes: 1, size left: 2441537
# 2023-09-23 17:38:17,048 INFO spark.SparkContext: Starting job: csv at DatasetReader.scala:99
# 2023-09-23 17:38:17,079 INFO scheduler.DAGScheduler: Got job 0 (csv at DatasetReader.scala:99) with 1 output partitions
# 2023-09-23 17:38:17,079 INFO scheduler.DAGScheduler: Final stage: ResultStage 0 (csv at DatasetReader.scala:99)
# 2023-09-23 17:38:17,080 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:17,081 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:17,105 INFO scheduler.DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[2] at csv at DatasetReader.scala:99), which has no missing parents
# 2023-09-23 17:38:17,145 INFO memory.MemoryStore: Block broadcast_1 stored as values in memory (estimated size 7.3 KiB, free 1458.1 MiB)
# 2023-09-23 17:38:17,148 INFO memory.MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 4.2 KiB, free 1458.1 MiB)
# 2023-09-23 17:38:17,149 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on 10.0.153.182:43091 (size: 4.2 KiB, free: 1458.6 MiB)
# 2023-09-23 17:38:17,150 INFO spark.SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:17,165 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[2] at csv at DatasetReader.scala:99) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:17,166 INFO cluster.YarnScheduler: Adding task set 0.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:17,204 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4640 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:17,481 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on algo-1:43953 (size: 4.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:18,323 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on algo-1:43953 (size: 39.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:18,601 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 1410 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:18,603 INFO cluster.YarnScheduler: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:18,610 INFO scheduler.DAGScheduler: ResultStage 0 (csv at DatasetReader.scala:99) finished in 1.476 s
# 2023-09-23 17:38:18,614 INFO scheduler.DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:18,614 INFO cluster.YarnScheduler: Killing all running tasks in stage 0: Stage finished
# 2023-09-23 17:38:18,616 INFO scheduler.DAGScheduler: Job 0 finished: csv at DatasetReader.scala:99, took 1.567510 s
# 2023-09-23 17:38:18,790 INFO storage.BlockManagerInfo: Removed broadcast_1_piece0 on 10.0.153.182:43091 in memory (size: 4.2 KiB, free: 1458.6 MiB)
# 2023-09-23 17:38:18,803 INFO storage.BlockManagerInfo: Removed broadcast_1_piece0 on algo-1:43953 in memory (size: 4.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:20,861 INFO datasources.FileSourceStrategy: Pushed Filters:
# 2023-09-23 17:38:20,862 INFO datasources.FileSourceStrategy: Post-Scan Filters:
# 2023-09-23 17:38:20,865 INFO datasources.FileSourceStrategy: Output Data Schema: struct<tGravityAcc-energy()-X: string, tGravityAcc-min()-X: string, tGravityAcc-max()-X: string, tGravityAcc-max()-Y: string, tGravityAcc-min()-Y: string ... 11 more fields>
# 2023-09-23 17:38:21,080 INFO memory.MemoryStore: Block broadcast_2 stored as values in memory (estimated size 416.5 KiB, free 1457.7 MiB)
# 2023-09-23 17:38:21,093 INFO memory.MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 39.2 KiB, free 1457.7 MiB)
# 2023-09-23 17:38:21,094 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on 10.0.153.182:43091 (size: 39.2 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:21,095 INFO spark.SparkContext: Created broadcast 2 from head at DataAnalyzer.scala:124
# 2023-09-23 17:38:21,109 INFO execution.FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 2023-09-23 17:38:21,151 INFO spark.SparkContext: Starting job: head at DataAnalyzer.scala:124
# 2023-09-23 17:38:21,153 INFO scheduler.DAGScheduler: Got job 1 (head at DataAnalyzer.scala:124) with 1 output partitions
# 2023-09-23 17:38:21,154 INFO scheduler.DAGScheduler: Final stage: ResultStage 1 (head at DataAnalyzer.scala:124)
# 2023-09-23 17:38:21,154 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:21,157 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:21,164 INFO scheduler.DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[11] at head at DataAnalyzer.scala:124), which has no missing parents
# 2023-09-23 17:38:21,230 INFO memory.MemoryStore: Block broadcast_3 stored as values in memory (estimated size 17.6 KiB, free 1457.7 MiB)
# 2023-09-23 17:38:21,232 INFO memory.MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 8.2 KiB, free 1457.7 MiB)
# 2023-09-23 17:38:21,233 INFO storage.BlockManagerInfo: Added broadcast_3_piece0 in memory on 10.0.153.182:43091 (size: 8.2 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:21,233 INFO spark.SparkContext: Created broadcast 3 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:21,234 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 1 (MapPartitionsRDD[11] at head at DataAnalyzer.scala:124) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:21,235 INFO cluster.YarnScheduler: Adding task set 1.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:21,240 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 1.0 (TID 1) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4968 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:21,278 INFO storage.BlockManagerInfo: Added broadcast_3_piece0 in memory on algo-1:43953 (size: 8.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:21,962 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on algo-1:43953 (size: 39.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:22,607 INFO storage.BlockManagerInfo: Added rdd_7_0 in memory on algo-1:43953 (size: 2.6 MiB, free: 5.8 GiB)
# 2023-09-23 17:38:23,631 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 1.0 (TID 1) in 2394 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:23,632 INFO cluster.YarnScheduler: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:23,635 INFO scheduler.DAGScheduler: ResultStage 1 (head at DataAnalyzer.scala:124) finished in 2.468 s
# 2023-09-23 17:38:23,636 INFO scheduler.DAGScheduler: Job 1 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:23,636 INFO cluster.YarnScheduler: Killing all running tasks in stage 1: Stage finished
# 2023-09-23 17:38:23,636 INFO scheduler.DAGScheduler: Job 1 finished: head at DataAnalyzer.scala:124, took 2.484365 s
# 2023-09-23 17:38:23,976 INFO codegen.CodeGenerator: Code generated in 283.062187 ms
# 2023-09-23 17:38:24,459 WARN util.package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2023-09-23 17:38:24,686 INFO scheduler.DAGScheduler: Registering RDD 16 (collect at AnalysisRunner.scala:326) as input to shuffle 0
# 2023-09-23 17:38:24,690 INFO scheduler.DAGScheduler: Got map stage job 2 (collect at AnalysisRunner.scala:326) with 1 output partitions
# 2023-09-23 17:38:24,690 INFO scheduler.DAGScheduler: Final stage: ShuffleMapStage 2 (collect at AnalysisRunner.scala:326)
# 2023-09-23 17:38:24,691 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:24,693 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:24,694 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 2 (MapPartitionsRDD[16] at collect at AnalysisRunner.scala:326), which has no missing parents
# 2023-09-23 17:38:24,713 INFO memory.MemoryStore: Block broadcast_4 stored as values in memory (estimated size 114.6 KiB, free 1457.6 MiB)
# 2023-09-23 17:38:24,715 INFO memory.MemoryStore: Block broadcast_4_piece0 stored as bytes in memory (estimated size 34.9 KiB, free 1457.5 MiB)
# 2023-09-23 17:38:24,715 INFO storage.BlockManagerInfo: Added broadcast_4_piece0 in memory on 10.0.153.182:43091 (size: 34.9 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:24,716 INFO spark.SparkContext: Created broadcast 4 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:24,717 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 2 (MapPartitionsRDD[16] at collect at AnalysisRunner.scala:326) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:24,717 INFO cluster.YarnScheduler: Adding task set 2.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:24,724 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 2.0 (TID 2) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4957 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:24,744 INFO storage.BlockManagerInfo: Added broadcast_4_piece0 in memory on algo-1:43953 (size: 34.9 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:26,065 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 2.0 (TID 2) in 1342 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:26,065 INFO cluster.YarnScheduler: Removed TaskSet 2.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:26,067 INFO scheduler.DAGScheduler: ShuffleMapStage 2 (collect at AnalysisRunner.scala:326) finished in 1.369 s
# 2023-09-23 17:38:26,067 INFO scheduler.DAGScheduler: looking for newly runnable stages
# 2023-09-23 17:38:26,068 INFO scheduler.DAGScheduler: running: Set()
# 2023-09-23 17:38:26,068 INFO scheduler.DAGScheduler: waiting: Set()
# 2023-09-23 17:38:26,069 INFO scheduler.DAGScheduler: failed: Set()
# 2023-09-23 17:38:26,142 INFO spark.SparkContext: Starting job: collect at AnalysisRunner.scala:326
# 2023-09-23 17:38:26,144 INFO scheduler.DAGScheduler: Got job 3 (collect at AnalysisRunner.scala:326) with 1 output partitions
# 2023-09-23 17:38:26,144 INFO scheduler.DAGScheduler: Final stage: ResultStage 4 (collect at AnalysisRunner.scala:326)
# 2023-09-23 17:38:26,144 INFO scheduler.DAGScheduler: Parents of final stage: List(ShuffleMapStage 3)
# 2023-09-23 17:38:26,145 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:26,145 INFO scheduler.DAGScheduler: Submitting ResultStage 4 (MapPartitionsRDD[19] at collect at AnalysisRunner.scala:326), which has no missing parents
# 2023-09-23 17:38:26,158 INFO memory.MemoryStore: Block broadcast_5 stored as values in memory (estimated size 167.8 KiB, free 1457.4 MiB)
# 2023-09-23 17:38:26,161 INFO memory.MemoryStore: Block broadcast_5_piece0 stored as bytes in memory (estimated size 46.0 KiB, free 1457.3 MiB)
# 2023-09-23 17:38:26,162 INFO storage.BlockManagerInfo: Added broadcast_5_piece0 in memory on 10.0.153.182:43091 (size: 46.0 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:26,163 INFO spark.SparkContext: Created broadcast 5 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:26,163 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 4 (MapPartitionsRDD[19] at collect at AnalysisRunner.scala:326) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:26,163 INFO cluster.YarnScheduler: Adding task set 4.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:26,166 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 4.0 (TID 3) (algo-1, executor 1, partition 0, NODE_LOCAL, 4464 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:26,185 INFO storage.BlockManagerInfo: Added broadcast_5_piece0 in memory on algo-1:43953 (size: 46.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:26,231 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 0 to 10.0.153.182:47044
# 2023-09-23 17:38:26,537 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 4.0 (TID 3) in 372 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:26,538 INFO cluster.YarnScheduler: Removed TaskSet 4.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:26,539 INFO scheduler.DAGScheduler: ResultStage 4 (collect at AnalysisRunner.scala:326) finished in 0.387 s
# 2023-09-23 17:38:26,539 INFO scheduler.DAGScheduler: Job 3 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:26,539 INFO cluster.YarnScheduler: Killing all running tasks in stage 4: Stage finished
# 2023-09-23 17:38:26,539 INFO scheduler.DAGScheduler: Job 3 finished: collect at AnalysisRunner.scala:326, took 0.397269 s
# 2023-09-23 17:38:26,602 INFO codegen.CodeGenerator: Code generated in 50.649212 ms
# 2023-09-23 17:38:26,912 INFO codegen.CodeGenerator: Code generated in 32.609474 ms
# 2023-09-23 17:38:26,987 INFO spark.SparkContext: Starting job: treeReduce at KLLRunner.scala:107
# 2023-09-23 17:38:26,989 INFO scheduler.DAGScheduler: Got job 4 (treeReduce at KLLRunner.scala:107) with 1 output partitions
# 2023-09-23 17:38:26,989 INFO scheduler.DAGScheduler: Final stage: ResultStage 5 (treeReduce at KLLRunner.scala:107)
# 2023-09-23 17:38:26,989 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:26,990 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:26,991 INFO scheduler.DAGScheduler: Submitting ResultStage 5 (MapPartitionsRDD[29] at treeReduce at KLLRunner.scala:107), which has no missing parents
# 2023-09-23 17:38:27,014 INFO memory.MemoryStore: Block broadcast_6 stored as values in memory (estimated size 38.4 KiB, free 1457.3 MiB)
# 2023-09-23 17:38:27,016 INFO memory.MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 16.3 KiB, free 1457.3 MiB)
# 2023-09-23 17:38:27,017 INFO storage.BlockManagerInfo: Added broadcast_6_piece0 in memory on 10.0.153.182:43091 (size: 16.3 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:27,017 INFO spark.SparkContext: Created broadcast 6 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:27,018 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 5 (MapPartitionsRDD[29] at treeReduce at KLLRunner.scala:107) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:27,018 INFO cluster.YarnScheduler: Adding task set 5.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:27,020 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 5.0 (TID 4) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4968 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:27,039 INFO storage.BlockManagerInfo: Added broadcast_6_piece0 in memory on algo-1:43953 (size: 16.3 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:27,632 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 5.0 (TID 4) in 613 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:27,633 INFO cluster.YarnScheduler: Removed TaskSet 5.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:27,633 INFO scheduler.DAGScheduler: ResultStage 5 (treeReduce at KLLRunner.scala:107) finished in 0.641 s
# 2023-09-23 17:38:27,633 INFO scheduler.DAGScheduler: Job 4 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:27,634 INFO cluster.YarnScheduler: Killing all running tasks in stage 5: Stage finished
# 2023-09-23 17:38:27,634 INFO scheduler.DAGScheduler: Job 4 finished: treeReduce at KLLRunner.scala:107, took 0.646219 s
# 2023-09-23 17:38:27,925 INFO storage.BlockManagerInfo: Removed broadcast_5_piece0 on algo-1:43953 in memory (size: 46.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:27,928 INFO storage.BlockManagerInfo: Removed broadcast_5_piece0 on 10.0.153.182:43091 in memory (size: 46.0 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:27,958 INFO storage.BlockManagerInfo: Removed broadcast_3_piece0 on algo-1:43953 in memory (size: 8.2 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:27,960 INFO storage.BlockManagerInfo: Removed broadcast_3_piece0 on 10.0.153.182:43091 in memory (size: 8.2 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:28,000 INFO storage.BlockManagerInfo: Removed broadcast_6_piece0 on 10.0.153.182:43091 in memory (size: 16.3 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:28,008 INFO storage.BlockManagerInfo: Removed broadcast_6_piece0 on algo-1:43953 in memory (size: 16.3 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:28,040 INFO storage.BlockManagerInfo: Removed broadcast_4_piece0 on algo-1:43953 in memory (size: 34.9 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:28,049 INFO storage.BlockManagerInfo: Removed broadcast_4_piece0 on 10.0.153.182:43091 in memory (size: 34.9 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:28,220 INFO codegen.CodeGenerator: Code generated in 106.675126 ms
# 2023-09-23 17:38:28,228 INFO scheduler.DAGScheduler: Registering RDD 34 (collect at AnalysisRunner.scala:326) as input to shuffle 1
# 2023-09-23 17:38:28,228 INFO scheduler.DAGScheduler: Got map stage job 5 (collect at AnalysisRunner.scala:326) with 1 output partitions
# 2023-09-23 17:38:28,229 INFO scheduler.DAGScheduler: Final stage: ShuffleMapStage 6 (collect at AnalysisRunner.scala:326)
# 2023-09-23 17:38:28,229 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:28,230 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:28,231 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 6 (MapPartitionsRDD[34] at collect at AnalysisRunner.scala:326), which has no missing parents
# 2023-09-23 17:38:28,237 INFO memory.MemoryStore: Block broadcast_7 stored as values in memory (estimated size 73.8 KiB, free 1457.6 MiB)
# 2023-09-23 17:38:28,239 INFO memory.MemoryStore: Block broadcast_7_piece0 stored as bytes in memory (estimated size 23.5 KiB, free 1457.6 MiB)
# 2023-09-23 17:38:28,239 INFO storage.BlockManagerInfo: Added broadcast_7_piece0 in memory on 10.0.153.182:43091 (size: 23.5 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:28,240 INFO spark.SparkContext: Created broadcast 7 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:28,240 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 6 (MapPartitionsRDD[34] at collect at AnalysisRunner.scala:326) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:28,240 INFO cluster.YarnScheduler: Adding task set 6.0 with 1 tasks resource profile 0
# ...
# 2023-09-23 17:38:33,667 INFO scheduler.DAGScheduler: Job 16 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:33,667 INFO cluster.YarnScheduler: Killing all running tasks in stage 22: Stage finished
# 2023-09-23 17:38:33,668 INFO scheduler.DAGScheduler: Job 16 finished: collect at AnalysisRunner.scala:326, took 0.066864 s
# 2023-09-23 17:38:33,714 INFO codegen.CodeGenerator: Code generated in 39.596971 ms
# 2023-09-23 17:38:33,808 INFO spark.SparkContext: Starting job: countByKey at ColumnProfiler.scala:592
# 2023-09-23 17:38:33,812 INFO scheduler.DAGScheduler: Registering RDD 97 (countByKey at ColumnProfiler.scala:592) as input to shuffle 6
# 2023-09-23 17:38:33,812 INFO scheduler.DAGScheduler: Got job 17 (countByKey at ColumnProfiler.scala:592) with 1 output partitions
# 2023-09-23 17:38:33,812 INFO scheduler.DAGScheduler: Final stage: ResultStage 24 (countByKey at ColumnProfiler.scala:592)
# 2023-09-23 17:38:33,812 INFO scheduler.DAGScheduler: Parents of final stage: List(ShuffleMapStage 23)
# 2023-09-23 17:38:33,812 INFO scheduler.DAGScheduler: Missing parents: List(ShuffleMapStage 23)
# 2023-09-23 17:38:33,814 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 23 (MapPartitionsRDD[97] at countByKey at ColumnProfiler.scala:592), which has no missing parents
# 2023-09-23 17:38:33,820 INFO memory.MemoryStore: Block broadcast_19 stored as values in memory (estimated size 30.6 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:33,821 INFO memory.MemoryStore: Block broadcast_19_piece0 stored as bytes in memory (estimated size 14.0 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:33,822 INFO storage.BlockManagerInfo: Added broadcast_19_piece0 in memory on 10.0.153.182:43091 (size: 14.0 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:33,823 INFO spark.SparkContext: Created broadcast 19 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:33,823 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 23 (MapPartitionsRDD[97] at countByKey at ColumnProfiler.scala:592) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:33,823 INFO cluster.YarnScheduler: Adding task set 23.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:33,825 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 23.0 (TID 17) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4957 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:33,833 INFO storage.BlockManagerInfo: Added broadcast_19_piece0 in memory on algo-1:43953 (size: 14.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,010 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 23.0 (TID 17) in 186 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:34,010 INFO cluster.YarnScheduler: Removed TaskSet 23.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:34,011 INFO scheduler.DAGScheduler: ShuffleMapStage 23 (countByKey at ColumnProfiler.scala:592) finished in 0.197 s
# 2023-09-23 17:38:34,012 INFO scheduler.DAGScheduler: looking for newly runnable stages
# 2023-09-23 17:38:34,012 INFO scheduler.DAGScheduler: running: Set()
# 2023-09-23 17:38:34,013 INFO scheduler.DAGScheduler: waiting: Set(ResultStage 24)
# 2023-09-23 17:38:34,013 INFO scheduler.DAGScheduler: failed: Set()
# 2023-09-23 17:38:34,013 INFO scheduler.DAGScheduler: Submitting ResultStage 24 (ShuffledRDD[98] at countByKey at ColumnProfiler.scala:592), which has no missing parents
# 2023-09-23 17:38:34,015 INFO memory.MemoryStore: Block broadcast_20 stored as values in memory (estimated size 5.1 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:34,017 INFO memory.MemoryStore: Block broadcast_20_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:34,017 INFO storage.BlockManagerInfo: Added broadcast_20_piece0 in memory on 10.0.153.182:43091 (size: 3.0 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,018 INFO spark.SparkContext: Created broadcast 20 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:34,019 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 24 (ShuffledRDD[98] at countByKey at ColumnProfiler.scala:592) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:34,019 INFO cluster.YarnScheduler: Adding task set 24.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:34,021 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 24.0 (TID 18) (algo-1, executor 1, partition 0, NODE_LOCAL, 4282 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:34,033 INFO storage.BlockManagerInfo: Added broadcast_20_piece0 in memory on algo-1:43953 (size: 3.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,039 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 6 to 10.0.153.182:47044
# 2023-09-23 17:38:34,062 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 24.0 (TID 18) in 42 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:34,062 INFO cluster.YarnScheduler: Removed TaskSet 24.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:34,063 INFO scheduler.DAGScheduler: ResultStage 24 (countByKey at ColumnProfiler.scala:592) finished in 0.049 s
# 2023-09-23 17:38:34,063 INFO scheduler.DAGScheduler: Job 17 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:34,063 INFO cluster.YarnScheduler: Killing all running tasks in stage 24: Stage finished
# 2023-09-23 17:38:34,064 INFO scheduler.DAGScheduler: Job 17 finished: countByKey at ColumnProfiler.scala:592, took 0.255748 s
# 2023-09-23 17:38:34,314 INFO FileUtil: Write to file constraints.json at path /opt/ml/processing/output.
# 2023-09-23 17:38:34,344 INFO codegen.CodeGenerator: Code generated in 8.117736 ms
# 2023-09-23 17:38:34,349 INFO scheduler.DAGScheduler: Registering RDD 103 (count at StatsGenerator.scala:66) as input to shuffle 7
# 2023-09-23 17:38:34,350 INFO scheduler.DAGScheduler: Got map stage job 18 (count at StatsGenerator.scala:66) with 1 output partitions
# 2023-09-23 17:38:34,350 INFO scheduler.DAGScheduler: Final stage: ShuffleMapStage 25 (count at StatsGenerator.scala:66)
# 2023-09-23 17:38:34,350 INFO scheduler.DAGScheduler: Parents of final stage: List()
# 2023-09-23 17:38:34,350 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:34,351 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 25 (MapPartitionsRDD[103] at count at StatsGenerator.scala:66), which has no missing parents
# 2023-09-23 17:38:34,354 INFO memory.MemoryStore: Block broadcast_21 stored as values in memory (estimated size 22.7 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:34,355 INFO memory.MemoryStore: Block broadcast_21_piece0 stored as bytes in memory (estimated size 10.4 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:34,356 INFO storage.BlockManagerInfo: Added broadcast_21_piece0 in memory on 10.0.153.182:43091 (size: 10.4 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,356 INFO spark.SparkContext: Created broadcast 21 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:34,358 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 25 (MapPartitionsRDD[103] at count at StatsGenerator.scala:66) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:34,358 INFO cluster.YarnScheduler: Adding task set 25.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:34,359 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 25.0 (TID 19) (algo-1, executor 1, partition 0, PROCESS_LOCAL, 4957 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:34,373 INFO storage.BlockManagerInfo: Added broadcast_21_piece0 in memory on algo-1:43953 (size: 10.4 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,410 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 25.0 (TID 19) in 51 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:34,411 INFO cluster.YarnScheduler: Removed TaskSet 25.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:34,412 INFO scheduler.DAGScheduler: ShuffleMapStage 25 (count at StatsGenerator.scala:66) finished in 0.060 s
# 2023-09-23 17:38:34,412 INFO scheduler.DAGScheduler: looking for newly runnable stages
# 2023-09-23 17:38:34,413 INFO scheduler.DAGScheduler: running: Set()
# 2023-09-23 17:38:34,413 INFO scheduler.DAGScheduler: waiting: Set()
# 2023-09-23 17:38:34,413 INFO scheduler.DAGScheduler: failed: Set()
# 2023-09-23 17:38:34,431 INFO codegen.CodeGenerator: Code generated in 6.205032 ms
# 2023-09-23 17:38:34,441 INFO spark.SparkContext: Starting job: count at StatsGenerator.scala:66
# 2023-09-23 17:38:34,442 INFO scheduler.DAGScheduler: Got job 19 (count at StatsGenerator.scala:66) with 1 output partitions
# 2023-09-23 17:38:34,442 INFO scheduler.DAGScheduler: Final stage: ResultStage 27 (count at StatsGenerator.scala:66)
# 2023-09-23 17:38:34,442 INFO scheduler.DAGScheduler: Parents of final stage: List(ShuffleMapStage 26)
# 2023-09-23 17:38:34,442 INFO scheduler.DAGScheduler: Missing parents: List()
# 2023-09-23 17:38:34,443 INFO scheduler.DAGScheduler: Submitting ResultStage 27 (MapPartitionsRDD[106] at count at StatsGenerator.scala:66), which has no missing parents
# 2023-09-23 17:38:34,444 INFO memory.MemoryStore: Block broadcast_22 stored as values in memory (estimated size 11.1 KiB, free 1457.1 MiB)
# 2023-09-23 17:38:34,446 INFO memory.MemoryStore: Block broadcast_22_piece0 stored as bytes in memory (estimated size 5.5 KiB, free 1457.0 MiB)
# 2023-09-23 17:38:34,446 INFO storage.BlockManagerInfo: Added broadcast_22_piece0 in memory on 10.0.153.182:43091 (size: 5.5 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,447 INFO spark.SparkContext: Created broadcast 22 from broadcast at DAGScheduler.scala:1513
# 2023-09-23 17:38:34,447 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 27 (MapPartitionsRDD[106] at count at StatsGenerator.scala:66) (first 15 tasks are for partitions Vector(0))
# 2023-09-23 17:38:34,447 INFO cluster.YarnScheduler: Adding task set 27.0 with 1 tasks resource profile 0
# 2023-09-23 17:38:34,448 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 27.0 (TID 20) (algo-1, executor 1, partition 0, NODE_LOCAL, 4464 bytes) taskResourceAssignments Map()
# 2023-09-23 17:38:34,458 INFO storage.BlockManagerInfo: Added broadcast_22_piece0 in memory on algo-1:43953 (size: 5.5 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,461 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 7 to 10.0.153.182:47044
# 2023-09-23 17:38:34,475 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 27.0 (TID 20) in 27 ms on algo-1 (executor 1) (1/1)
# 2023-09-23 17:38:34,475 INFO cluster.YarnScheduler: Removed TaskSet 27.0, whose tasks have all completed, from pool
# 2023-09-23 17:38:34,475 INFO scheduler.DAGScheduler: ResultStage 27 (count at StatsGenerator.scala:66) finished in 0.032 s
# 2023-09-23 17:38:34,476 INFO scheduler.DAGScheduler: Job 19 is finished. Cancelling potential speculative or zombie tasks for this job
# 2023-09-23 17:38:34,476 INFO cluster.YarnScheduler: Killing all running tasks in stage 27: Stage finished
# 2023-09-23 17:38:34,476 INFO scheduler.DAGScheduler: Job 19 finished: count at StatsGenerator.scala:66, took 0.034881 s
# 2023-09-23 17:38:34,594 INFO storage.BlockManagerInfo: Removed broadcast_18_piece0 on 10.0.153.182:43091 in memory (size: 11.1 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,595 INFO storage.BlockManagerInfo: Removed broadcast_18_piece0 on algo-1:43953 in memory (size: 11.1 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,621 INFO storage.BlockManagerInfo: Removed broadcast_13_piece0 on 10.0.153.182:43091 in memory (size: 19.1 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,643 INFO storage.BlockManagerInfo: Removed broadcast_13_piece0 on algo-1:43953 in memory (size: 19.1 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,696 INFO storage.BlockManagerInfo: Removed broadcast_22_piece0 on 10.0.153.182:43091 in memory (size: 5.5 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,697 INFO storage.BlockManagerInfo: Removed broadcast_22_piece0 on algo-1:43953 in memory (size: 5.5 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,709 INFO storage.BlockManagerInfo: Removed broadcast_21_piece0 on algo-1:43953 in memory (size: 10.4 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,711 INFO storage.BlockManagerInfo: Removed broadcast_21_piece0 on 10.0.153.182:43091 in memory (size: 10.4 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,720 INFO storage.BlockManagerInfo: Removed broadcast_20_piece0 on 10.0.153.182:43091 in memory (size: 3.0 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,720 INFO storage.BlockManagerInfo: Removed broadcast_20_piece0 on algo-1:43953 in memory (size: 3.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,751 INFO storage.BlockManagerInfo: Removed broadcast_16_piece0 on 10.0.153.182:43091 in memory (size: 16.4 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,752 INFO storage.BlockManagerInfo: Removed broadcast_16_piece0 on algo-1:43953 in memory (size: 16.4 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,800 INFO storage.BlockManagerInfo: Removed broadcast_15_piece0 on algo-1:43953 in memory (size: 35.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,800 INFO storage.BlockManagerInfo: Removed broadcast_15_piece0 on 10.0.153.182:43091 in memory (size: 35.0 KiB, free: 1458.4 MiB)
# 2023-09-23 17:38:34,827 INFO storage.BlockManagerInfo: Removed broadcast_19_piece0 on algo-1:43953 in memory (size: 14.0 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,828 INFO storage.BlockManagerInfo: Removed broadcast_19_piece0 on 10.0.153.182:43091 in memory (size: 14.0 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:34,884 INFO storage.BlockManagerInfo: Removed broadcast_17_piece0 on 10.0.153.182:43091 in memory (size: 16.4 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:34,886 INFO storage.BlockManagerInfo: Removed broadcast_17_piece0 on algo-1:43953 in memory (size: 16.4 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,907 INFO storage.BlockManagerInfo: Removed broadcast_14_piece0 on algo-1:43953 in memory (size: 22.6 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:34,908 INFO storage.BlockManagerInfo: Removed broadcast_14_piece0 on 10.0.153.182:43091 in memory (size: 22.6 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:34,936 INFO storage.BlockManagerInfo: Removed broadcast_12_piece0 on 10.0.153.182:43091 in memory (size: 23.6 KiB, free: 1458.5 MiB)
# 2023-09-23 17:38:34,938 INFO storage.BlockManagerInfo: Removed broadcast_12_piece0 on algo-1:43953 in memory (size: 23.6 KiB, free: 5.8 GiB)
# 2023-09-23 17:38:35,052 INFO FileUtil: Write to file statistics.json at path /opt/ml/processing/output.
# 2023-09-23 17:38:35,073 INFO cluster.YarnClientSchedulerBackend: Interrupting monitor thread
# 2023-09-23 17:38:35,116 INFO cluster.YarnClientSchedulerBackend: Shutting down all executors
# 2023-09-23 17:38:35,116 INFO cluster.YarnSchedulerBackend$YarnDriverEndpoint: Asking each executor to shut down
# 2023-09-23 17:38:35,126 INFO cluster.YarnClientSchedulerBackend: YARN client scheduler backend Stopped
# 2023-09-23 17:38:35,142 INFO spark.MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 2023-09-23 17:38:35,193 INFO memory.MemoryStore: MemoryStore cleared
# 2023-09-23 17:38:35,193 INFO storage.BlockManager: BlockManager stopped
# 2023-09-23 17:38:35,199 INFO storage.BlockManagerMaster: BlockManagerMaster stopped
# 2023-09-23 17:38:35,217 INFO scheduler.OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 2023-09-23 17:38:35,275 INFO spark.SparkContext: Successfully stopped SparkContext
# 2023-09-23 17:38:35,275 INFO Main: Completed: Job completed successfully with no violations.
# 2023-09-23 17:38:35,275 INFO Main: Write to file /opt/ml/output/message.
# 2023-09-23 17:38:35,301 INFO util.ShutdownHookManager: Shutdown hook called
# 2023-09-23 17:38:35,302 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-6c553921-3e48-474a-9e09-fd2be8b0638d
# 2023-09-23 17:38:35,313 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-adbd7d4a-350c-4cc2-9c59-9b1e7c1fb3b2
# 2023-09-23 17:38:35,380 - DefaultDataAnalyzer - INFO - Completed spark-submit with return code : 0
# 2023-09-23 17:38:35,380 - DefaultDataAnalyzer - INFO - Spark job completed.

# %%
s3_client = boto3.Session().client("s3")
result = s3_client.list_objects(Bucket=bucket, Prefix=baseline_results_prefix)
report_files = [report_file.get("Key") for report_file in result.get("Contents")]
print("Found Files:")
print("\n ".join(report_files))

# %%
from pandas import json_normalize
baseline_job = my_default_monitor.latest_baselining_job
schema_df = json_normalize(baseline_job.baseline_statistics().body_dict["features"])
schema_df.head(10)

# %%
constraints_df = json_normalize(
    baseline_job.suggested_constraints().body_dict["features"]
)
constraints_df.head(10)

# %% [markdown]
# ## Monitor Schedule

# %%
from sagemaker.model_monitor import CronExpressionGenerator
from sagemaker.model_monitor import BatchTransformInput
from sagemaker.model_monitor import MonitoringDatasetFormat
from time import gmtime, strftime

statistics_path = "{}/statistics.json".format(baseline_results_uri)
constraints_path = "{}/constraints.json".format(baseline_results_uri)

mon_schedule_name = "DEMO-mlops1-model-monitor-schedule-" + strftime(
    "%Y-%m-%d-%H-%M-%S", gmtime()
)
my_default_monitor.create_monitoring_schedule(
    monitor_schedule_name=mon_schedule_name,
    batch_transform_input=BatchTransformInput(
        data_captured_destination_s3_uri=s3_capture_upload_path,
        destination="/opt/ml/processing/input",
        dataset_format=MonitoringDatasetFormat.csv(header=False),
    ),
    output_s3_uri=s3_report_path,
    statistics=statistics_path,
    constraints=constraints_path,
    schedule_cron_expression=CronExpressionGenerator.hourly(),
    enable_cloudwatch_metrics=True,
)
# Out:
# INFO:sagemaker.model_monitor.model_monitoring:Creating Monitoring Schedule with name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43

# %%
desc_schedule_result = my_default_monitor.describe_schedule()
print("Schedule status: {}".format(desc_schedule_result["MonitoringScheduleStatus"]))
# Out:
# Schedule status: Scheduled

# %%
import time

mon_executions = my_default_monitor.list_executions()
print(
    "We created a hourly schedule above and it will kick off executions ON the hour (plus 0 - 20 min buffer.\nWe will have to wait till we hit the hour..."
)

while len(mon_executions) == 0:
    print("Waiting for the 1st execution to happen...")
    time.sleep(60)
    mon_executions = my_default_monitor.list_executions()
# Out:
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# We created a hourly schedule above and it will kick off executions ON the hour (plus 0 - 20 min buffer.
# We will have to wait till we hit the hour...
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...
# No executions found for schedule. monitoring_schedule_name: DEMO-mlops1-model-monitor-schedule-2023-09-23-07-51-43
# Waiting for the 1st execution to happen...

# %%
latest_execution = mon_executions[
    -1
]  # latest execution's index is -1, second to last is -2 and so on..
# time.sleep(60)
latest_execution.wait(logs=False)

print("Latest execution status: {}".format(latest_execution.describe()["ProcessingJobStatus"]))
print("Latest execution result: {}".format(latest_execution.describe()["ExitMessage"]))

latest_job = latest_execution.describe()
if latest_job["ProcessingJobStatus"] != "Completed":
    print(
        "====STOP==== \n No completed executions to inspect further. Please wait till an execution completes or investigate previously reported failures."
    )
# Out:
# !Latest execution status: Completed
# Latest execution result: CompletedWithViolations: Job completed successfully with 1 violations.

# %%
report_uri = latest_execution.output.destination
print("Report Uri: {}".format(report_uri))
# Out:
# Report Uri: s3://sagemaker-studio-009676737623-l4vs7j0o0ib/mlops-level1-data/reports/DEMO-xgb-churn-pred-model-monitor-schedule-2023-09-21-17-54-46/2023/09/21/18

# %%
from urllib.parse import urlparse

s3uri = urlparse(report_uri)
report_bucket = s3uri.netloc
report_key = s3uri.path.lstrip("/")
print("Report bucket: {}".format(report_bucket))
print("Report key: {}".format(report_key))

s3_client = boto3.Session().client("s3")
result = s3_client.list_objects(Bucket=report_bucket, Prefix=report_key)
report_files = [report_file.get("Key") for report_file in result.get("Contents")]
print("Found Report Files:")
print("\n ".join(report_files))
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# Report bucket: sagemaker-studio-009676737623-l4vs7j0o0ib
# Report key: mlops-level1-data/reports/DEMO-xgb-churn-pred-model-monitor-schedule-2023-09-21-17-54-46/2023/09/21/18
# Found Report Files:
# mlops-level1-data/reports/DEMO-xgb-churn-pred-model-monitor-schedule-2023-09-21-17-54-46/2023/09/21/18/constraint_violations.json

# %%
violations = my_default_monitor.latest_monitoring_constraint_violations()
#pd.set_option("display.max_colwidth", -1)
constraints_df = json_normalize(violations.body_dict["violations"])
constraints_df.head(10)
# Out:
#       feature_name constraint_check_type  \
# 0  Missing columns  missing_column_check
#
#                                          description
# 0  There are missing columns in current dataset. ...
