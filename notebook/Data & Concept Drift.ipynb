# %%
import pandas as pd
import joblib
from sklearn.preprocessing import LabelEncoder
import evidently

# %%
v1_df = pd.read_parquet('/Users/apal/Documents/PathtoAI/AnalyticsVidhya/Mlops/data/data_drift/v1.gzip')
v2_df = pd.read_parquet('/Users/apal/Documents/PathtoAI/AnalyticsVidhya/Mlops/data/data_drift/v2.gzip')

# %%
v1_df['Activity'].value_counts()
# Out:
# LAYING                16762
# WALKING               16728
# WALKING_UPSTAIRS      16675
# STANDING              16645
# WALKING_DOWNSTAIRS    16627
# SITTING               16563
# Name: Activity, dtype: int64

# %%
v2_df['Activity'].value_counts()
# Out:
# SITTING               28827
# LAYING                16762
# WALKING_UPSTAIRS      16675
# STANDING              16645
# WALKING_DOWNSTAIRS    16627
# WALKING                4464
# Name: Activity, dtype: int64

# %%
le = LabelEncoder()
v1_df['Activity'] = le.fit_transform(v1_df['Activity'])
v2_df['Activity'] = le.fit_transform(v2_df['Activity'])

# %%
v1_df.rename({'Activity':'target'}, axis =1,inplace = True)
v2_df.rename({'Activity':'target'}, axis =1,inplace = True)

# %% [markdown]
# ### Prediction

# %%
## Load Features and model weight
train_features = joblib.load("./model_features/train_features.joblib")

model = joblib.load("./model_weights/my_random_forest.joblib")

# %%
train_features
# Out:
# array(['tGravityAcc-energy()-X', 'angle(X,gravityMean)',
#        'tGravityAcc-mean()-X', 'tGravityAcc-min()-Y',
#        'tGravityAcc-max()-X', 'tGravityAcc-max()-Y',
#        'tGravityAcc-min()-X', 'tGravityAcc-mean()-Y',
#        'angle(Y,gravityMean)', 'fBodyAccJerk-entropy()-Y'], dtype=object)

# %%
## V1 prediction
v1_test_features = v1_df[train_features]
v1_df['prediction'] = model.predict(v1_test_features)

# %%
## V2 prediction
v2_test_features = v2_df[train_features]
v2_df['prediction'] = model.predict(v2_test_features)

# %% [markdown]
# ### There has been a Software update and we have data from both V1 and V2 softwares
#
# #### Let's compare both the data and see of there has been any data drift

# %% [markdown]
# ### Data Drift

# %%
#!pip install evidently

# %%
#pip install somelibrary

# %%
from evidently.report import Report

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset
from evidently.test_preset import DataQualityTestPreset
from evidently.metric_preset import TargetDriftPreset, DataQualityPreset
from evidently.metric_preset import DataDriftPreset , ClassificationPreset

# %%
data_drift_report = Report(metrics=[
    DataDriftPreset(),
])

data_drift_report.run(reference_data=v1_df, current_data=v2_df)

# %%
data_drift_report.save_html("../output/data_drift_report.html")

# %% [markdown]
# ### Data Quality Report

# %%
data_quality_report = Report(metrics=[
    DataQualityPreset(),
])

data_quality_report.run(reference_data=v1_df, current_data=v2_df)
data_quality_report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_6ffe242a807e454c804c4d56a6c81faa = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "706d1db6-65d5-4386-834d-9b2d2d8f5525", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "", "size": 2, "id": "b88ee996-b957-41ff-8032-ea3d54dba91e", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Current", "Reference"], "data": [["id column", "None", "None"], ["target column", "target", "target"], ["prediction column", "prediction", "prediction"], ["date column", "None", "None"], ["number of columns", "13", "13"], ["number of rows", "100000", "100000"], ["missing values", "0", "0"], ["categorical columns", "0", "0"], ["numeric columns", "10", "10"], ["text columns", "0", "0"], ["datetime columns", "1", "1"], ["empty columns", "0", "0"], ["constant columns", "0", "0"], ["almost constant features", "0", "0"], ["duplicated columns", "0", "0"], ["almost duplicated features", "0", "0"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "rich_data", "title": "", "size": 2, "id": "363a9f92-7fe1-476a-97e0-a3439cfc6f07", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": "angle(X,gravityMean)", "description": "num", "metricsValuesHeaders": ["current", "reference"], "metrics": [{"label": "count", "values": ["100000", "100000"]}, {"label": "mean", "values": ["-0.26", "-0.26"]}, {"label": "std", "values": ["0.32", "0.32"]}, {"label": "min", "values": ["-0.99", "-0.99"]}, {"label": "25%", "values": ["-0.5", "-0.5"]}, {"label": "50%", "values": ["-0.28", "-0.28"]}, {"label": "75%", "values": ["-0.07", "-0.07"]}, {"label": "max", "values": ["0.95", "0.95"]}, {"label": "unique", "values": ["100000 (100.0%)", "100000 (100.0%)"]}, {"label": "most common", "values": ["-0.48779 (0.0%)", "-0.48779 (0.0%)"]}, {"label": "missing", "values": ["0 (0.0%)", "0 (0.0%)"]}, {"label": "infinite", "values": ["0 (0.0%)", "0 (0.0%)"]}], "graph": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "x": [-0.9922459681288827, -0.9175886546070277, -0.8429313410851726, -0.7682740275633178, -0.6936167140414627, -0.6189594005196077, -0.5443020869977528, -0.46964477347589784, -0.39498745995404283, -0.3203301464321878, -0.24567283291033282, -0.17101551938847792, -0.09635820586662291, -0.021700892344767908, 0.05295642117708699, 0.1276137346989421, 0.202271048220797, 0.2769283617426519, 0.351585675264507, 0.4262429887863619, 0.500900302308217, 0.5755576158300719, 0.6502149293519268, 0.7248722428737819, 0.7995295563956368, 0.8741868699174917], "y": [80, 804, 2505, 4313, 5842, 7022, 7819, 8400, 8738, 8610, 8765, 8716, 8916, 4440, 2622, 2535, 2606, 2485, 1918, 1412, 819, 349, 172, 75, 29, 8], "type": "bar"}, {"marker": {"color": "#ed0400"}, "name": "current", "visible": false, "x": [-4.151392450255825, -3.979367977343207, -3.8073435044305888, -3.635319031517971, -3.4632945586053525, -3.2912700856927346, -3.1192456127801167, -2.9472211398674983, -2.77519666695488, -2.603172194042262, -2.431147721129644, -2.259123248217026, -2.087098775304408, -1.9150743023917896, -1.7430498294791716, -1.5710253565665533, -1.3990008836539354, -1.2269764107413175, -1.0549519378286991, -0.8829274649160812, -0.7109029920034629, -0.5388785190908449, -0.3668540461782266, -0.19482957326560868], "y": [2, 2, 5, 3, 7, 12, 7, 18, 30, 43, 58, 97, 158, 190, 307, 451, 701, 1031, 1498, 2170, 3300, 4037, 2450, 330], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "x": [-0.9922459681288827, -0.9175886546070277, -0.8429313410851726, -0.7682740275633178, -0.6936167140414627, -0.6189594005196077, -0.5443020869977528, -0.46964477347589784, -0.39498745995404283, -0.3203301464321878, -0.24567283291033282, -0.17101551938847792, -0.09635820586662291, -0.0217008 ...

# %%
data_quality_report.save_html("../output/data_quality_report.html")

# %% [markdown]
# ### Concept Drift

# %%
num_target_drift_report = Report(metrics=[
    TargetDriftPreset(),
])

num_target_drift_report.run(reference_data=v1_df, current_data=v2_df)

# %%
num_target_drift_report.save_html("../output/concept_drift_report.html")

# %%
classification_performance_report = Report(metrics=[
    ClassificationPreset(),
])

classification_performance_report.run(reference_data=v1_df, current_data=v2_df)

classification_performance_report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_370773949cd14f30bffde82cf99f15de = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "9433fee0-78a4-4b3d-aba5-8b5dc252bbb5", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Classification Model Performance. Target: 'target\u2019"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "Current: Model Quality Metrics", "size": 2, "id": "82597d05-e3e0-452c-989f-a0fed280afb2", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "0.689", "label": "Accuracy"}, {"value": "0.664", "label": "Precision"}, {"value": "0.672", "label": "Recall"}, {"value": "0.648", "label": "F1"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "Reference: Model Quality Metrics", "size": 2, "id": "c0fc8892-55be-4b7e-a0b7-901f9342e4cc", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "0.76", "label": "Accuracy"}, {"value": "0.757", "label": "Precision"}, {"value": "0.76", "label": "Recall"}, {"value": "0.755", "label": "F1"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "bdfc49a8-0dab-4128-845c-76e16301811a", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Class Representation"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "big_graph", "title": "", "size": 2, "id": "cb46dab6-25ca-4cd4-9e1e-3c2d4646f94b", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "visible": true, "x": ["1", "0", "5", "2", "4", "3"], "y": [28827, 16762, 16675, 16645, 16627, 4464], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#ed0400"}, "name": "current", "visible": false, "x": ["1", "0", "5", "2", "4", "3"], "y": [28.827, 16.762, 16.675, 16.645, 16.627, 4.4639999999999995], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#ed0400"}, "name": "reference", "visible": true, "x": ["0", "3", "5", "2", "4", "1"], "y": [16762, 16728, 16675, 16645, 16627, 16563], "type": "bar", "xaxis": "x2", "yaxis": "y2"}, {"marker": {"color": "#ed0400"}, "name": "reference", "visible": false, "x": ["0", "3", "5", "2", "4", "1"], "y": [16.762, 16.728, 16.675, 16.645, 16.627, 16.563], "type": "bar", "xaxis": "x2", "yaxis": "y2"}], "layout": {"template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ti ...

# %%
classification_performance_report.save_html("../output/classification_performance_report.html")
